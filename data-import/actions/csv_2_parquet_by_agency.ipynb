# %%
import os
import pandas as pd
from pyproj import Proj, transform

def csv_to_single_row_dataframe(file_path):
    # Read the CSV file
    df = pd.read_csv(file_path)
    
    # Use the first column as headers and the second column as row values
    single_row_df = pd.DataFrame([df.iloc[:, 1].values], columns=df.iloc[:, 0].values)
    
    return single_row_df

def merge_header_and_data(header_path, data_path):
    header_df = csv_to_single_row_dataframe(header_path)
    selected_columns = ['Agency Code', 'Program', 'Project', 'Tag', 'Data File Name', 'Location', 'Station Status', 'Lat', 'Long', 'Time Zone', 'Vertical Datum', 'National Station ID', 'Site Description', 'Deployment', 'Deployment Position', 'Vertical Reference', 'Variable ID']
    header_df = header_df[selected_columns]
    data_df = pd.read_csv(data_path)
    
    # Repeat the header for each row in the data DataFrame
    header_repeated = pd.concat([header_df] * len(data_df), ignore_index=True)
    
    # Combine the header and data DataFrames
    combined_df = pd.concat([header_repeated, data_df], axis=1)
    
    # Rename columns as requested
    combined_df.rename(columns={
        'Tag': 'Agency',
        'Agency Code': 'Agency_Code',
        'Program': 'Program_Name',
        'Project': 'Program_Code',
        'Date': 'Date',
        'Data': 'Data',
        'Depth': 'Depth',
        'Variable ID': 'Variable_ID',
        'Variable': 'Variable_Name',
        'Data File Name': 'Data_File_Name',
        'Location': 'Data_File_Location',
        'Station Status': 'Status',
        'Lat': 'Lat',
        'Long': 'Lon',
        'Time Zone': 'Time_Zone',
        'Vertical Datum': 'Vertical_Datum',
        'National Station ID': 'Station_ID',
        'Site Description': 'Site_Description',
        'Deployment': 'Deployment',
        'Deployment Position': 'Deployment_Postion',
        'Vertical Reference': 'Vertical_Reference'
    }, inplace=True)
    
    # Add new columns with default values
    combined_df['calc_SMD'] = 0.0
    combined_df['mAHD'] = 0.0
    
    # Convert Lat and Lon to UTM coordinates (XUTM, YUTM)
    in_proj = Proj(init='epsg:4326')  # WGS84 coordinates (Lat, Lon)
    out_proj = Proj(init='epsg:32755')  # UTM Zone 55S
    
    def convert_to_utm(lat, lon):
        x, y = transform(in_proj, out_proj, lon, lat)
        return x, y
    
    combined_df['XUTM'], combined_df['YUTM'] = zip(*combined_df.apply(lambda row: convert_to_utm(row['Lat'], row['Lon']), axis=1))

    # Load variable key data
    variable_key_df = pd.read_csv('../../data-governance/variable_key.csv')
    
    # Merge with variable key to get Units
    combined_df = pd.merge(combined_df, variable_key_df[['Variable ID', 'Units']], left_on='Variable_ID', right_on='Variable ID', how='left')
    
    # Rearrange columns as requested
    column_order = ['Agency', 'Agency_Code', 'Program_Name', 'Program_Code', 'Date', 'Data', 'Depth', 'Variable_ID', 'Variable_Name', 'Units', 'Data_File_Name', 'Data_File_Location', 'Status', 'Lat', 'Lon', 'XUTM', 'YUTM', 'Time_Zone', 'Vertical_Datum', 'Station_ID', 'Site_Description', 'Deployment', 'Deployment_Postion', 'Vertical_Reference', 'calc_SMD', 'mAHD']
    combined_df = combined_df[column_order]
    
    return combined_df

def find_csv_header_files(directory):
    csv_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith("Header.csv"):
                csv_files.append(os.path.join(root, file))
    return csv_files

def find_csv_data_files(directory):
    csv_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith("Data.csv"):
                csv_files.append(os.path.join(root, file))
    return csv_files

directory = "../../data-warehouse/csv/ht"

header_files = find_csv_header_files(directory)
data_files = find_csv_data_files(directory)

combined_df = pd.DataFrame([])
csv_file_path = "../../data-warehouse/parquet/agency/test_csiem_HT_public.csv"

# Match header files with corresponding data files
for header_file in header_files:
    # Construct the corresponding data file path
    data_file = header_file.replace("_Header.csv", "_Data.csv")
    
    # Ensure the data file exists before processing
    if data_file in data_files:
        print( f"start processing: {header_file} and {data_file}")
        combined_df = merge_header_and_data(header_file, data_file)

        if os.path.exists(csv_file_path):
            combined_df.to_csv(csv_file_path, mode='a', header=None, index=False)
        else:
            combined_df.to_csv(csv_file_path, mode='a', index=False)

        print( f"{header_file} and {data_file} processed")
    else:
        print(f"Data file not found for {header_file}")

# Export combined_df as Parquet file
final_df = pd.read_csv(csv_file_path)
parquet_file_path = "../../data-warehouse/parquet/agency/test_csiem_HT_public.parq"
print(f"Combined DataFrame exported to {parquet_file_path}")
final_df.to_parquet(parquet_file_path, index=False)
# Out:
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Unidentifiedfilamentouscyanobacteria_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Unidentifiedfilamentouscyanobacteria_profile_Data.csv
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Unidentifiedfilamentouscyanobacteria_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Unidentifiedfilamentouscyanobacteria_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chlorophyll-a_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chlorophyll-a_profile_Data.csv
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chlorophyll-a_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chlorophyll-a_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_DissolvedOxygen_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_DissolvedOxygen_profile_Data.csv
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_DissolvedOxygen_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_DissolvedOxygen_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Charophyta(Elakatothrixsp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Charophyta(Elakatothrixsp.)_profile_Data.csv
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Charophyta(Elakatothrixsp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Charophyta(Elakatothrixsp.)_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chlorophyta(Mougeotiasp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chlorophyta(Mougeotiasp.)_profile_Data.csv
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chlorophyta(Mougeotiasp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chlorophyta(Mougeotiasp.)_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Dinophyta(Peridiniumsp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Dinophyta(Peridiniumsp.)_profile_Data.csv
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Dinophyta(Peridiniumsp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Dinophyta(Peridiniumsp.)_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_pH_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_pH_profile_Data.csv
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_pH_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_pH_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Ochrophyta(Uroglenasp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Ochrophyta(Uroglenasp.)_profile_Data.csv
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Ochrophyta(Uroglenasp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Ochrophyta(Uroglenasp.)_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Ochrophyta(Kephyrionsp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Ochrophyta(Kephyrionsp.)_profile_Data.csv
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Ochrophyta(Kephyrionsp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Ochrophyta(Kephyrionsp.)_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Bacillariophyta(Cymbellahauckii)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Bacillariophyta(Cymbellahauckii)_profile_Data.csv
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Bacillariophyta(Cymbellahauckii)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Bacillariophyta(Cymbellahauckii)_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Cyanobacteria(Aphanothecesp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Cyanobacteria(Aphanothecesp.)_profile_Data.csv
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Cyanobacteria(Aphanothecesp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Cyanobacteria(Aphanothecesp.)_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Ochrophyta(Ophiocytiaceaesp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Ochrophyta(Ophiocytiaceaesp.)_profile_Data.csv
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Ochrophyta(Ophiocytiaceaesp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Ochrophyta(Ophiocytiaceaesp.)_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_AirTemperature_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_AirTemperature_profile_Data.csv
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_AirTemperature_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_AirTemperature_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_WindSpeedEstimate_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_WindSpeedEstimate_profile_Data.csv
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_WindSpeedEstimate_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_WindSpeedEstimate_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Nitrate_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Nitrate_profile_Data.csv
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Nitrate_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Nitrate_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chrysophyta(Dinobryonsp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chrysophyta(Dinobryonsp.)_profile_Data.csv
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chrysophyta(Dinobryonsp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chrysophyta(Dinobryonsp.)_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Cyanobacteria(Aphanizomenonsp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Cyanobacteria(Aphanizomenonsp.)_profile_Data.csv
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Cyanobacteria(Aphanizomenonsp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Cyanobacteria(Aphanizomenonsp.)_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chlorophyta(Botryococcussp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chlorophyta(Botryococcussp.)_profile_Data.csv
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chlorophyta(Botryococcussp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chlorophyta(Botryococcussp.)_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chlorophyta(Dictyosphaeriumsp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chlorophyta(Dictyosphaeriumsp.)_profile_Data.csv
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chlorophyta(Dictyosphaeriumsp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chlorophyta(Dictyosphaeriumsp.)_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Cyanobacteria(Aphanothecesp.1)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Cyanobacteria(Aphanothecesp.1)_profile_Data.csv
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Cyanobacteria(Aphanothecesp.1)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Cyanobacteria(Aphanothecesp.1)_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chromista(Unidentifieddinoflagellate)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chromista(Unidentifieddinoflagellate)_profile_Data.csv
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chromista(Unidentifieddinoflagellate)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chromista(Unidentifieddinoflagellate)_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Discharge(Inflow)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Discharge(Inflow)_profile_Data.csv
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Discharge(Inflow)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Discharge(Inflow)_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_TotalKjeldahiNitrogen_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_TotalKjeldahiNitrogen_profile_Data.csv
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_TotalKjeldahiNitrogen_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_TotalKjeldahiNitrogen_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Samplebottles_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Samplebottles_profile_Data.csv
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Samplebottles_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Samplebottles_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Unidentifiedchlorophyte_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Unidentifiedchlorophyte_profile_Data.csv
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Unidentifiedchlorophyte_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Unidentifiedchlorophyte_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chlorophyta(Micractiniumsp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chlorophyta(Micractiniumsp.)_profile_Data.csv
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chlorophyta(Micractiniumsp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Chlorophyta(Micractiniumsp.)_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_WaterSurfaceHeight_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_WaterSurfaceHeight_profile_Data.csv
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_WaterSurfaceHeight_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_WaterSurfaceHeight_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Cryptophyta(Cryptomonassp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Cryptophyta(Cryptomonassp.)_profile_Data.csv
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Cryptophyta(Cryptomonassp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Cryptophyta(Cryptomonassp.)_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Euglenophyta(Euglenasp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Euglenophyta(Euglenasp.)_profile_Data.csv
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Euglenophyta(Euglenasp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Euglenophyta(Euglenasp.)_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_WaterSurfaceCondition_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_WaterSurfaceCondition_profile_Data.csv
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_WaterSurfaceCondition_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_WaterSurfaceCondition_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Bacillariophyta(Achnanthessp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Bacillariophyta(Achnanthessp.)_profile_Data.csv
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Bacillariophyta(Achnanthessp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Bacillariophyta(Achnanthessp.)_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Unidentifieduniflagellate_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Unidentifieduniflagellate_profile_Data.csv
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Unidentifieduniflagellate_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Unidentifieduniflagellate_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Dinophyta(Gymnodiniumsp.)_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_Dinophyta(Gymnodiniumsp.)_profile_Data.csv
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# ...
# ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_TotalAlkalinity_profile_Header.csv and ../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_TotalAlkalinity_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/met/BOMIDC_Precipitation_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOMIDC_Precipitation_profile_Data.csv
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# ../../data-warehouse/csv/ht/met/BOMIDC_Precipitation_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOMIDC_Precipitation_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/met/BOM_WindDirection_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOM_WindDirection_profile_Data.csv
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# ../../data-warehouse/csv/ht/met/BOM_WindDirection_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOM_WindDirection_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/met/BOM_AirTemperature_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOM_AirTemperature_profile_Data.csv
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# ../../data-warehouse/csv/ht/met/BOM_AirTemperature_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOM_AirTemperature_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/met/BOM_RelativeHumidity_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOM_RelativeHumidity_profile_Data.csv
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# ../../data-warehouse/csv/ht/met/BOM_RelativeHumidity_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOM_RelativeHumidity_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/met/BOM_Precipitation_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOM_Precipitation_profile_Data.csv
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# ../../data-warehouse/csv/ht/met/BOM_Precipitation_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOM_Precipitation_profile_Data.csv processed
# start processing: ../../data-warehouse/csv/ht/met/BOM_WindSpeed_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOM_WindSpeed_profile_Data.csv
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1299362492.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 109
#     107 if data_file in data_files:
#     108     print( f"start processing: {header_file} and {data_file}")
# --> 109     combined_df = merge_header_and_data(header_file, data_file)
#     111     if os.path.exists(csv_file_path):
#     112         combined_df.to_csv(csv_file_path, mode='a', header=None, index=False)
#
# Cell In[47], line 63, in merge_header_and_data(header_path, data_path)
#      60     x, y = transform(in_proj, out_proj, lon, lat)
#      61     return x, y
# ---> 63 combined_df['XUTM'], combined_df['YUTM'] = zip(*combined_df.apply(lambda row: convert_to_utm(row['Lat'], row['Lon']), axis=1))
#      65 # Load variable key data
#      66 variable_key_df = pd.read_csv('../../data-governance/variable_key.csv')
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/frame.py:10037, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10025 from pandas.core.apply import frame_apply
#   10027 op = frame_apply(
#   10028     self,
#   10029     func=func,
#    (...)
#   10035     kwargs=kwargs,
#   10036 )
# > 10037 return op.apply().__finalize__(self, method="apply")
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/apply.py:837, in FrameApply.apply(self)
#     834 elif self.raw:
#     835     return self.apply_raw()
# --> 837 return self.apply_standard()
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/apply.py:963, in FrameApply.apply_standard(self)
#     962 def apply_standard(self):
# --> 963     results, res_index = self.apply_series_generator()
#     965     # wrap results
#     966     return self.wrap_results(results, res_index)
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/apply.py:979, in FrameApply.apply_series_generator(self)
#     976 with option_context("mode.chained_assignment", None):
#     977     for i, v in enumerate(series_gen):
#     978         # ignore SettingWithCopy here in case the user mutates
# --> 979         results[i] = self.func(v, *self.args, **self.kwargs)
#     980         if isinstance(results[i], ABCSeries):
#     981             # If we have a view on v, we need to make a copy because
#     982             #  series_generator will swap out the underlying data
#     983             results[i] = results[i].copy(deep=False)
#
# Cell In[47], line 63, in merge_header_and_data.<locals>.<lambda>(row)
#      60     x, y = transform(in_proj, out_proj, lon, lat)
#      61     return x, y
# ---> 63 combined_df['XUTM'], combined_df['YUTM'] = zip(*combined_df.apply(lambda row: convert_to_utm(row['Lat'], row['Lon']), axis=1))
#      65 # Load variable key data
#      66 variable_key_df = pd.read_csv('../../data-governance/variable_key.csv')
#
# Cell In[47], line 60, in merge_header_and_data.<locals>.convert_to_utm(lat, lon)
#      59 def convert_to_utm(lat, lon):
# ---> 60     x, y = transform(in_proj, out_proj, lon, lat)
#      61     return x, y
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/transformer.py:1256, in transform(p1, p2, x, y, z, tt, radians, errcheck, always_xy)
#    1207 """
#    1208 .. versionadded:: 2.2.0 always_xy
#    1209
#    (...)
#    1245
#    1246 """
#    1247 warnings.warn(
#    1248     (
#    1249         "This function is deprecated. "
#    (...)
#    1254     stacklevel=2,
#    1255 )
# -> 1256 return Transformer.from_proj(p1, p2, always_xy=always_xy).transform(
#    1257     xx=x, yy=y, zz=z, tt=tt, radians=radians, errcheck=errcheck
#    1258 )
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/transformer.py:545, in Transformer.from_proj(proj_from, proj_to, always_xy, area_of_interest)
#     542 if not isinstance(proj_to, Proj):
#     543     proj_to = Proj(proj_to)
# --> 545 return Transformer.from_crs(
#     546     proj_from.crs,
#     547     proj_to.crs,
#     548     always_xy=always_xy,
#     549     area_of_interest=area_of_interest,
#     550 )
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/transformer.py:625, in Transformer.from_crs(crs_from, crs_to, always_xy, area_of_interest, authority, accuracy, allow_ballpark, force_over, only_best)
#     552 @staticmethod
#     553 def from_crs(
#     554     crs_from: Any,
#    (...)
#     562     only_best: Optional[bool] = None,
#     563 ) -> "Transformer":
#     564     """Make a Transformer from a :obj:`pyproj.crs.CRS` or input used to create one.
#     565
#     566     See:
#    (...)
#     623
#     624     """
# --> 625     return Transformer(
#     626         TransformerFromCRS(
#     627             cstrencode(CRS.from_user_input(crs_from).srs),
#     628             cstrencode(CRS.from_user_input(crs_to).srs),
#     629             always_xy=always_xy,
#     630             area_of_interest=area_of_interest,
#     631             authority=authority,
#     632             accuracy=accuracy if accuracy is None else str(accuracy),
#     633             allow_ballpark=allow_ballpark,
#     634             force_over=force_over,
#     635             only_best=only_best,
#     636         )
#     637     )
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/transformer.py:337, in Transformer.__init__(self, transformer_maker)
#     331     raise ProjError(
#     332         "Transformer must be initialized using: "
#     333         "'from_crs' or 'from_pipeline'."
#     334     )
#     336 self._local = TransformerLocal()
# --> 337 self._local.transformer = transformer_maker()
#     338 self._transformer_maker = transformer_maker
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/transformer.py:105, in TransformerFromCRS.__call__(self)
#      99 def __call__(self) -> _Transformer:
#     100     """
#     101     Returns
#     102     -------
#     103     _Transformer
#     104     """
# --> 105     return _Transformer.from_crs(
#     106         self.crs_from,
#     107         self.crs_to,
#     108         always_xy=self.always_xy,
#     109         area_of_interest=self.area_of_interest,
#     110         authority=self.authority,
#     111         accuracy=self.accuracy,
#     112         allow_ballpark=self.allow_ballpark,
#     113         force_over=self.force_over,
#     114         only_best=self.only_best,
#     115     )
#
# KeyboardInterrupt:

# %%
import os
import pandas as pd
from pyproj import Proj, transform

def csv_to_single_row_dataframe(file_path):
    # Read the CSV file
    df = pd.read_csv(file_path)
    
    # Use the first column as headers and the second column as row values
    single_row_df = pd.DataFrame([df.iloc[:, 1].values], columns=df.iloc[:, 0].values)
    
    return single_row_df

def merge_header_and_data(header_path, data_path):
    header_df = csv_to_single_row_dataframe(header_path)
    selected_columns = ['Agency Code', 'Program', 'Project', 'Tag', 'Data File Name', 'Location', 'Station Status', 'Lat', 'Long', 'Time Zone', 'Vertical Datum', 'National Station ID', 'Site Description', 'Deployment', 'Deployment Position', 'Vertical Reference', 'Variable ID']
    header_df = header_df[selected_columns]
    data_df = pd.read_csv(data_path)
    
    # Repeat the header for each row in the data DataFrame
    header_repeated = pd.concat([header_df] * len(data_df), ignore_index=True)
    
    # Combine the header and data DataFrames
    combined_df = pd.concat([header_repeated, data_df], axis=1)
    
    # Rename columns as requested
    combined_df.rename(columns={
        'Tag': 'Agency-str',
        'Agency Code': 'Agency_Code-str',
        'Program': 'Program_Name-str',
        'Project': 'Program_Code-str',
        'Date': 'Date-str',
        'Data': 'Data-f64',
        'Depth': 'Depth-f64',
        'Variable ID': 'Variable_ID-str',
        'Variable': 'Variable_Name-str',
        'Data File Name': 'Data_File_Name-str',
        'Location': 'Data_File_Location-str',
        'Station Status': 'Status-str',
        'Lat': 'Lat-f64',
        'Long': 'Lon-f64',
        'Time Zone': 'Time_Zone-str',
        'Vertical Datum': 'Vertical_Datum-str',
        'National Station ID': 'Station_ID-str',
        'Site Description': 'Site_Description-str',
        'Deployment': 'Deployment-str',
        'Deployment Position': 'Deployment_Postion-str',
        'Vertical Reference': 'Vertical_Reference-str'
    }, inplace=True)
    
    # Add new columns with default values
    combined_df['calc_SMD-f64'] = 0.0
    combined_df['mAHD-f64'] = 0.0
    
    # Convert Lat-f64 and Lon-f64 to UTM coordinates (XUTM-f64, YUTM-f64)
    in_proj = Proj(init='epsg:4326')  # WGS84 coordinates (Lat, Lon)
    out_proj = Proj(init='epsg:32755')  # UTM Zone 55S
    
    def convert_to_utm(lat, lon):
        x, y = transform(in_proj, out_proj, lon, lat)
        return x, y
    
    combined_df['XUTM-f64'], combined_df['YUTM-f64'] = zip(*combined_df.apply(lambda row: convert_to_utm(row['Lat-f64'], row['Lon-f64']), axis=1))

    # Load variable key data
    variable_key_df = pd.read_csv('../../data-governance/variable_key.csv')
    
    # Merge with variable key to get Units
    combined_df = pd.merge(combined_df, variable_key_df[['Variable ID', 'Units']], left_on='Variable_ID-str', right_on='Variable ID', how='left')
    
    # Rename Units column to 'Units-str'
    combined_df.rename(columns={'Units': 'Units-str'}, inplace=True)
    
    # Rearrange columns as requested
    column_order = ['Agency-str', 'Agency_Code-str', 'Program_Name-str', 'Program_Code-str', 'Date-str', 'Data-f64', 'Depth-f64', 'Variable_ID-str', 'Variable_Name-str', 'Units-str', 'Data_File_Name-str', 'Data_File_Location-str', 'Status-str', 'Lat-f64', 'Lon-f64', 'XUTM-f64', 'YUTM-f64', 'Time_Zone-str', 'Vertical_Datum-str', 'Station_ID-str', 'Site_Description-str', 'Deployment-str', 'Deployment_Postion-str', 'Vertical_Reference-str', 'calc_SMD-f64', 'mAHD-f64']
    combined_df = combined_df[column_order]
    
    return combined_df

def find_csv_header_files(directory):
    csv_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith("Header.csv"):
                csv_files.append(os.path.join(root, file))
    return csv_files

def find_csv_data_files(directory):
    csv_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith("Data.csv"):
                csv_files.append(os.path.join(root, file))
    return csv_files

directory = "../../data-warehouse/csv/ht/met"

header_files = find_csv_header_files(directory)
data_files = find_csv_data_files(directory)

# Match header files with corresponding data files
for header_file in header_files:
    # Construct the corresponding data file path
    data_file = header_file.replace("_Header.csv", "_Data.csv")
    
    # Ensure the data file exists before processing
    if data_file in data_files:
        combined_df = merge_header_and_data(header_file, data_file)
        print(f"Combined DataFrame for {header_file} and {data_file}:")
        print(combined_df.head())
        print()
    else:
        print(f"Data file not found for {header_file}")
# Out:
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1888926299.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# Combined DataFrame for ../../data-warehouse/csv/ht/met/BOMIDC_Precipitation_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOMIDC_Precipitation_profile_Data.csv:
#   Agency-str Agency_Code-str Program_Name-str Program_Code-str  \
# 0     HT-MET              HT              BOM              MET
# 1     HT-MET              HT              BOM              MET
# 2     HT-MET              HT              BOM              MET
# 3     HT-MET              HT              BOM              MET
# 4     HT-MET              HT              BOM              MET
#
#               Date-str  Data-f64  Depth-f64 Variable_ID-str Variable_Name-str  \
# 0  2000-01-01 00:00:00       NaN          0        var00152        IDCJAC0009
# 1  2000-01-02 00:00:00       NaN          0        var00152        IDCJAC0009
# 2  2000-01-03 00:00:00       NaN          0        var00152        IDCJAC0009
# 3  2000-01-04 00:00:00       NaN          0        var00152        IDCJAC0009
# 4  2000-01-05 00:00:00       NaN          0        var00152        IDCJAC0009
#
#   Units-str  ...      YUTM-f64 Time_Zone-str Vertical_Datum-str  \
# 0         m  ...  5.361274e+06        GMT +6               mAHD
# 1         m  ...  5.361274e+06        GMT +6               mAHD
# 2         m  ...  5.361274e+06        GMT +6               mAHD
# 3         m  ...  5.361274e+06        GMT +6               mAHD
# 4         m  ...  5.361274e+06        GMT +6               mAHD
#
#   Station_ID-str Site_Description-str  Deployment-str  Deployment_Postion-str  \
# 0          96033                96033         Profile          m from Surface
# 1          96033                96033         Profile          m from Surface
# 2          96033                96033         Profile          m from Surface
# 3          96033                96033         Profile          m from Surface
# 4          96033                96033         Profile          m from Surface
#
#   Vertical_Reference-str calc_SMD-f64 mAHD-f64
# 0          Water Surface          0.0      0.0
# 1          Water Surface          0.0      0.0
# 2          Water Surface          0.0      0.0
# 3          Water Surface          0.0      0.0
# 4          Water Surface          0.0      0.0
#
# [5 rows x 26 columns]
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1888926299.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 108
#     106 # Ensure the data file exists before processing
#     107 if data_file in data_files:
# --> 108     combined_df = merge_header_and_data(header_file, data_file)
#     109     print(f"Combined DataFrame for {header_file} and {data_file}:")
#     110     print(combined_df.head())
#
# Cell In[28], line 63, in merge_header_and_data(header_path, data_path)
#      60     x, y = transform(in_proj, out_proj, lon, lat)
#      61     return x, y
# ---> 63 combined_df['XUTM-f64'], combined_df['YUTM-f64'] = zip(*combined_df.apply(lambda row: convert_to_utm(row['Lat-f64'], row['Lon-f64']), axis=1))
#      65 # Load variable key data
#      66 variable_key_df = pd.read_csv('../../data-governance/variable_key.csv')
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/frame.py:10037, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10025 from pandas.core.apply import frame_apply
#   10027 op = frame_apply(
#   10028     self,
#   10029     func=func,
#    (...)
#   10035     kwargs=kwargs,
#   10036 )
# > 10037 return op.apply().__finalize__(self, method="apply")
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/apply.py:837, in FrameApply.apply(self)
#     834 elif self.raw:
#     835     return self.apply_raw()
# --> 837 return self.apply_standard()
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/apply.py:963, in FrameApply.apply_standard(self)
#     962 def apply_standard(self):
# --> 963     results, res_index = self.apply_series_generator()
#     965     # wrap results
#     966     return self.wrap_results(results, res_index)
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/apply.py:979, in FrameApply.apply_series_generator(self)
#     976 with option_context("mode.chained_assignment", None):
#     977     for i, v in enumerate(series_gen):
#     978         # ignore SettingWithCopy here in case the user mutates
# --> 979         results[i] = self.func(v, *self.args, **self.kwargs)
#     980         if isinstance(results[i], ABCSeries):
#     981             # If we have a view on v, we need to make a copy because
#     982             #  series_generator will swap out the underlying data
#     983             results[i] = results[i].copy(deep=False)
#
# Cell In[28], line 63, in merge_header_and_data.<locals>.<lambda>(row)
#      60     x, y = transform(in_proj, out_proj, lon, lat)
#      61     return x, y
# ---> 63 combined_df['XUTM-f64'], combined_df['YUTM-f64'] = zip(*combined_df.apply(lambda row: convert_to_utm(row['Lat-f64'], row['Lon-f64']), axis=1))
#      65 # Load variable key data
#      66 variable_key_df = pd.read_csv('../../data-governance/variable_key.csv')
#
# Cell In[28], line 60, in merge_header_and_data.<locals>.convert_to_utm(lat, lon)
#      59 def convert_to_utm(lat, lon):
# ---> 60     x, y = transform(in_proj, out_proj, lon, lat)
#      61     return x, y
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/transformer.py:1256, in transform(p1, p2, x, y, z, tt, radians, errcheck, always_xy)
#    1207 """
#    1208 .. versionadded:: 2.2.0 always_xy
#    1209
#    (...)
#    1245
#    1246 """
#    1247 warnings.warn(
#    1248     (
#    1249         "This function is deprecated. "
#    (...)
#    1254     stacklevel=2,
#    1255 )
# -> 1256 return Transformer.from_proj(p1, p2, always_xy=always_xy).transform(
#    1257     xx=x, yy=y, zz=z, tt=tt, radians=radians, errcheck=errcheck
#    1258 )
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/transformer.py:545, in Transformer.from_proj(proj_from, proj_to, always_xy, area_of_interest)
#     542 if not isinstance(proj_to, Proj):
#     543     proj_to = Proj(proj_to)
# --> 545 return Transformer.from_crs(
#     546     proj_from.crs,
#     547     proj_to.crs,
#     548     always_xy=always_xy,
#     549     area_of_interest=area_of_interest,
#     550 )
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/transformer.py:625, in Transformer.from_crs(crs_from, crs_to, always_xy, area_of_interest, authority, accuracy, allow_ballpark, force_over, only_best)
#     552 @staticmethod
#     553 def from_crs(
#     554     crs_from: Any,
#    (...)
#     562     only_best: Optional[bool] = None,
#     563 ) -> "Transformer":
#     564     """Make a Transformer from a :obj:`pyproj.crs.CRS` or input used to create one.
#     565
#     566     See:
#    (...)
#     623
#     624     """
# --> 625     return Transformer(
#     626         TransformerFromCRS(
#     627             cstrencode(CRS.from_user_input(crs_from).srs),
#     628             cstrencode(CRS.from_user_input(crs_to).srs),
#     629             always_xy=always_xy,
#     630             area_of_interest=area_of_interest,
#     631             authority=authority,
#     632             accuracy=accuracy if accuracy is None else str(accuracy),
#     633             allow_ballpark=allow_ballpark,
#     634             force_over=force_over,
#     635             only_best=only_best,
#     636         )
#     637     )
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/transformer.py:337, in Transformer.__init__(self, transformer_maker)
#     331     raise ProjError(
#     332         "Transformer must be initialized using: "
#     333         "'from_crs' or 'from_pipeline'."
#     334     )
#     336 self._local = TransformerLocal()
# --> 337 self._local.transformer = transformer_maker()
#     338 self._transformer_maker = transformer_maker
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/transformer.py:105, in TransformerFromCRS.__call__(self)
#      99 def __call__(self) -> _Transformer:
#     100     """
#     101     Returns
#     102     -------
#     103     _Transformer
#     104     """
# --> 105     return _Transformer.from_crs(
#     106         self.crs_from,
#     107         self.crs_to,
#     108         always_xy=self.always_xy,
#     109         area_of_interest=self.area_of_interest,
#     110         authority=self.authority,
#     111         accuracy=self.accuracy,
#     112         allow_ballpark=self.allow_ballpark,
#     113         force_over=self.force_over,
#     114         only_best=self.only_best,
#     115     )
#
# KeyboardInterrupt:

# %%
import os
import pandas as pd
from pyproj import Proj, transform

def csv_to_single_row_dataframe(file_path):
    # Read the CSV file
    df = pd.read_csv(file_path)
    
    # Use the first column as headers and the second column as row values
    single_row_df = pd.DataFrame([df.iloc[:, 1].values], columns=df.iloc[:, 0].values)
    
    return single_row_df

def merge_header_and_data(header_path, data_path):
    header_df = csv_to_single_row_dataframe(header_path)
    selected_columns = ['Agency Code', 'Program', 'Project', 'Tag', 'Data File Name', 'Location', 'Station Status', 'Lat', 'Long', 'Time Zone', 'Vertical Datum', 'National Station ID', 'Site Description', 'Deployment', 'Deployment Position', 'Vertical Reference', 'Variable ID']
    header_df = header_df[selected_columns]
    data_df = pd.read_csv(data_path)
    
    # Repeat the header for each row in the data DataFrame
    header_repeated = pd.concat([header_df] * len(data_df), ignore_index=True)
    
    # Combine the header and data DataFrames
    combined_df = pd.concat([header_repeated, data_df], axis=1)
    
    # Rename columns as requested
    combined_df.rename(columns={
        'Tag': 'Agency-str',
        'Agency Code': 'Agency_Code-str',
        'Program': 'Program_Name-str',
        'Project': 'Program_Code-str',
        'Date': 'Date-str',
        'Data': 'Data-f64',
        'Depth': 'Depth-f64',
        'Variable ID': 'Variable_ID-str',
        'Variable': 'Variable_Name-str',
        'Data File Name': 'Data_File_Name-str',
        'Location': 'Data_File_Location-str',
        'Station Status': 'Status-str',
        'Lat': 'Lat-f64',
        'Long': 'Lon-f64',
        'Time Zone': 'Time_Zone-str',
        'Vertical Datum': 'Vertical_Datum-str',
        'National Station ID': 'Station_ID-str',
        'Site Description': 'Site_Description-str',
        'Deployment': 'Deployment-str',
        'Deployment Position': 'Deployment_Postion-str',
        'Vertical Reference': 'Vertical_Reference-str'
    }, inplace=True)
    
    # Add new columns with default values
    combined_df['calc_SMD-f64'] = 0.0
    combined_df['mAHD-f64'] = 0.0
    
    # Convert Lat-f64 and Lon-f64 to UTM coordinates (XUTM-f64, YUTM-f64)
    in_proj = Proj(init='epsg:4326')  # WGS84 coordinates (Lat, Lon)
    out_proj = Proj(init='epsg:32755')  # UTM Zone 55S
    
    def convert_to_utm(lat, lon):
        x, y = transform(in_proj, out_proj, lon, lat)
        return x, y
    
    combined_df['XUTM-f64'], combined_df['YUTM-f64'] = zip(*combined_df.apply(lambda row: convert_to_utm(row['Lat-f64'], row['Lon-f64']), axis=1))

    # Rearrange columns as requested
    column_order = ['Agency-str', 'Agency_Code-str', 'Program_Name-str', 'Program_Code-str', 'Date-str', 'Data-f64', 'Depth-f64', 'Variable_ID-str', 'Variable_Name-str', 'Data_File_Name-str', 'Data_File_Location-str', 'Status-str', 'Lat-f64', 'Lon-f64', 'XUTM-f64', 'YUTM-f64', 'Time_Zone-str', 'Vertical_Datum-str', 'Station_ID-str', 'Site_Description-str', 'Deployment-str', 'Deployment_Postion-str', 'Vertical_Reference-str', 'calc_SMD-f64', 'mAHD-f64']
    combined_df = combined_df[column_order]
    
    return combined_df

def find_csv_header_files(directory):
    csv_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith("Header.csv"):
                csv_files.append(os.path.join(root, file))
    return csv_files

def find_csv_data_files(directory):
    csv_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith("Data.csv"):
                csv_files.append(os.path.join(root, file))
    return csv_files

directory = "../../data-warehouse/csv/ht/met"

header_files = find_csv_header_files(directory)
data_files = find_csv_data_files(directory)

# Match header files with corresponding data files
for header_file in header_files:
    # Construct the corresponding data file path
    data_file = header_file.replace("_Header.csv", "_Data.csv")
    
    # Ensure the data file exists before processing
    if data_file in data_files:
        combined_df = merge_header_and_data(header_file, data_file)
        print(f"Combined DataFrame for {header_file} and {data_file}:")
        print(combined_df.head())
        print()
    else:
        print(f"Data file not found for {header_file}")
# Out:
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1245765032.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# Combined DataFrame for ../../data-warehouse/csv/ht/met/BOMIDC_Precipitation_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOMIDC_Precipitation_profile_Data.csv:
#   Agency-str Agency_Code-str Program_Name-str Program_Code-str  \
# 0     HT-MET              HT              BOM              MET
# 1     HT-MET              HT              BOM              MET
# 2     HT-MET              HT              BOM              MET
# 3     HT-MET              HT              BOM              MET
# 4     HT-MET              HT              BOM              MET
#
#               Date-str  Data-f64  Depth-f64 Variable_ID-str Variable_Name-str  \
# 0  2000-01-01 00:00:00       NaN          0        var00152        IDCJAC0009
# 1  2000-01-02 00:00:00       NaN          0        var00152        IDCJAC0009
# 2  2000-01-03 00:00:00       NaN          0        var00152        IDCJAC0009
# 3  2000-01-04 00:00:00       NaN          0        var00152        IDCJAC0009
# 4  2000-01-05 00:00:00       NaN          0        var00152        IDCJAC0009
#
#   Data_File_Name-str  ...      YUTM-f64 Time_Zone-str Vertical_Datum-str  \
# 0     IDCJAC0009.csv  ...  5.361274e+06        GMT +6               mAHD
# 1     IDCJAC0009.csv  ...  5.361274e+06        GMT +6               mAHD
# 2     IDCJAC0009.csv  ...  5.361274e+06        GMT +6               mAHD
# 3     IDCJAC0009.csv  ...  5.361274e+06        GMT +6               mAHD
# 4     IDCJAC0009.csv  ...  5.361274e+06        GMT +6               mAHD
#
#   Station_ID-str  Site_Description-str  Deployment-str Deployment_Postion-str  \
# 0          96033                 96033         Profile         m from Surface
# 1          96033                 96033         Profile         m from Surface
# 2          96033                 96033         Profile         m from Surface
# 3          96033                 96033         Profile         m from Surface
# 4          96033                 96033         Profile         m from Surface
#
#   Vertical_Reference-str calc_SMD-f64 mAHD-f64
# 0          Water Surface          0.0      0.0
# 1          Water Surface          0.0      0.0
# 2          Water Surface          0.0      0.0
# 3          Water Surface          0.0      0.0
# 4          Water Surface          0.0      0.0
#
# [5 rows x 25 columns]
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /Users/yvette/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/1245765032.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 99
#      97 # Ensure the data file exists before processing
#      98 if data_file in data_files:
# ---> 99     combined_df = merge_header_and_data(header_file, data_file)
#     100     print(f"Combined DataFrame for {header_file} and {data_file}:")
#     101     print(combined_df.head())
#
# Cell In[26], line 63, in merge_header_and_data(header_path, data_path)
#      60     x, y = transform(in_proj, out_proj, lon, lat)
#      61     return x, y
# ---> 63 combined_df['XUTM-f64'], combined_df['YUTM-f64'] = zip(*combined_df.apply(lambda row: convert_to_utm(row['Lat-f64'], row['Lon-f64']), axis=1))
#      65 # Rearrange columns as requested
#      66 column_order = ['Agency-str', 'Agency_Code-str', 'Program_Name-str', 'Program_Code-str', 'Date-str', 'Data-f64', 'Depth-f64', 'Variable_ID-str', 'Variable_Name-str', 'Data_File_Name-str', 'Data_File_Location-str', 'Status-str', 'Lat-f64', 'Lon-f64', 'XUTM-f64', 'YUTM-f64', 'Time_Zone-str', 'Vertical_Datum-str', 'Station_ID-str', 'Site_Description-str', 'Deployment-str', 'Deployment_Postion-str', 'Vertical_Reference-str', 'calc_SMD-f64', 'mAHD-f64']
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/frame.py:10037, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10025 from pandas.core.apply import frame_apply
#   10027 op = frame_apply(
#   10028     self,
#   10029     func=func,
#    (...)
#   10035     kwargs=kwargs,
#   10036 )
# > 10037 return op.apply().__finalize__(self, method="apply")
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/apply.py:837, in FrameApply.apply(self)
#     834 elif self.raw:
#     835     return self.apply_raw()
# --> 837 return self.apply_standard()
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/apply.py:963, in FrameApply.apply_standard(self)
#     962 def apply_standard(self):
# --> 963     results, res_index = self.apply_series_generator()
#     965     # wrap results
#     966     return self.wrap_results(results, res_index)
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/apply.py:979, in FrameApply.apply_series_generator(self)
#     976 with option_context("mode.chained_assignment", None):
#     977     for i, v in enumerate(series_gen):
#     978         # ignore SettingWithCopy here in case the user mutates
# --> 979         results[i] = self.func(v, *self.args, **self.kwargs)
#     980         if isinstance(results[i], ABCSeries):
#     981             # If we have a view on v, we need to make a copy because
#     982             #  series_generator will swap out the underlying data
#     983             results[i] = results[i].copy(deep=False)
#
# Cell In[26], line 63, in merge_header_and_data.<locals>.<lambda>(row)
#      60     x, y = transform(in_proj, out_proj, lon, lat)
#      61     return x, y
# ---> 63 combined_df['XUTM-f64'], combined_df['YUTM-f64'] = zip(*combined_df.apply(lambda row: convert_to_utm(row['Lat-f64'], row['Lon-f64']), axis=1))
#      65 # Rearrange columns as requested
#      66 column_order = ['Agency-str', 'Agency_Code-str', 'Program_Name-str', 'Program_Code-str', 'Date-str', 'Data-f64', 'Depth-f64', 'Variable_ID-str', 'Variable_Name-str', 'Data_File_Name-str', 'Data_File_Location-str', 'Status-str', 'Lat-f64', 'Lon-f64', 'XUTM-f64', 'YUTM-f64', 'Time_Zone-str', 'Vertical_Datum-str', 'Station_ID-str', 'Site_Description-str', 'Deployment-str', 'Deployment_Postion-str', 'Vertical_Reference-str', 'calc_SMD-f64', 'mAHD-f64']
#
# Cell In[26], line 60, in merge_header_and_data.<locals>.convert_to_utm(lat, lon)
#      59 def convert_to_utm(lat, lon):
# ---> 60     x, y = transform(in_proj, out_proj, lon, lat)
#      61     return x, y
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/transformer.py:1256, in transform(p1, p2, x, y, z, tt, radians, errcheck, always_xy)
#    1207 """
#    1208 .. versionadded:: 2.2.0 always_xy
#    1209
#    (...)
#    1245
#    1246 """
#    1247 warnings.warn(
#    1248     (
#    1249         "This function is deprecated. "
#    (...)
#    1254     stacklevel=2,
#    1255 )
# -> 1256 return Transformer.from_proj(p1, p2, always_xy=always_xy).transform(
#    1257     xx=x, yy=y, zz=z, tt=tt, radians=radians, errcheck=errcheck
#    1258 )
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/transformer.py:545, in Transformer.from_proj(proj_from, proj_to, always_xy, area_of_interest)
#     542 if not isinstance(proj_to, Proj):
#     543     proj_to = Proj(proj_to)
# --> 545 return Transformer.from_crs(
#     546     proj_from.crs,
#     547     proj_to.crs,
#     548     always_xy=always_xy,
#     549     area_of_interest=area_of_interest,
#     550 )
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/transformer.py:625, in Transformer.from_crs(crs_from, crs_to, always_xy, area_of_interest, authority, accuracy, allow_ballpark, force_over, only_best)
#     552 @staticmethod
#     553 def from_crs(
#     554     crs_from: Any,
#    (...)
#     562     only_best: Optional[bool] = None,
#     563 ) -> "Transformer":
#     564     """Make a Transformer from a :obj:`pyproj.crs.CRS` or input used to create one.
#     565
#     566     See:
#    (...)
#     623
#     624     """
# --> 625     return Transformer(
#     626         TransformerFromCRS(
#     627             cstrencode(CRS.from_user_input(crs_from).srs),
#     628             cstrencode(CRS.from_user_input(crs_to).srs),
#     629             always_xy=always_xy,
#     630             area_of_interest=area_of_interest,
#     631             authority=authority,
#     632             accuracy=accuracy if accuracy is None else str(accuracy),
#     633             allow_ballpark=allow_ballpark,
#     634             force_over=force_over,
#     635             only_best=only_best,
#     636         )
#     637     )
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/transformer.py:337, in Transformer.__init__(self, transformer_maker)
#     331     raise ProjError(
#     332         "Transformer must be initialized using: "
#     333         "'from_crs' or 'from_pipeline'."
#     334     )
#     336 self._local = TransformerLocal()
# --> 337 self._local.transformer = transformer_maker()
#     338 self._transformer_maker = transformer_maker
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/transformer.py:105, in TransformerFromCRS.__call__(self)
#      99 def __call__(self) -> _Transformer:
#     100     """
#     101     Returns
#     102     -------
#     103     _Transformer
#     104     """
# --> 105     return _Transformer.from_crs(
#     106         self.crs_from,
#     107         self.crs_to,
#     108         always_xy=self.always_xy,
#     109         area_of_interest=self.area_of_interest,
#     110         authority=self.authority,
#     111         accuracy=self.accuracy,
#     112         allow_ballpark=self.allow_ballpark,
#     113         force_over=self.force_over,
#     114         only_best=self.only_best,
#     115     )
#
# KeyboardInterrupt:

# %%
import os
import pandas as pd
from pyproj import Proj, transform

def csv_to_single_row_dataframe(file_path):
    # Read the CSV file
    df = pd.read_csv(file_path)
    
    # Use the first column as headers and the second column as row values
    single_row_df = pd.DataFrame([df.iloc[:, 1].values], columns=df.iloc[:, 0].values)
    
    return single_row_df

def merge_header_and_data(header_path, data_path):
    header_df = csv_to_single_row_dataframe(header_path)
    selected_columns = ['Agency Code', 'Program', 'Project', 'Tag', 'Data File Name', 'Location', 'Station Status', 'Lat', 'Long', 'Time Zone', 'Vertical Datum', 'National Station ID', 'Site Description', 'Deployment', 'Deployment Position', 'Vertical Reference', 'Variable ID']
    header_df = header_df[selected_columns]
    data_df = pd.read_csv(data_path)
    
    # Repeat the header for each row in the data DataFrame
    header_repeated = pd.concat([header_df] * len(data_df), ignore_index=True)
    
    # Combine the header and data DataFrames
    combined_df = pd.concat([header_repeated, data_df], axis=1)
    
    # Rename columns as requested
    combined_df.rename(columns={
        'Tag': 'Agency-str',
        'Agency Code': 'Agency_Code-str',
        'Program': 'Program_Name-str',
        'Project': 'Program_Code-str',
        'Date': 'Date-str',
        'Data': 'Data-f64',
        'Depth': 'Depth-f64',
        'Variable ID': 'Variable_ID-str',
        'Variable': 'Variable_Name-str',
        'Data File Name': 'Data_File_Name-str',
        'Location': 'Data_File_Location-str',
        'Station Status': 'Status-str',
        'Lat': 'Lat-f64',
        'Long': 'Lon-f64',
        'Time Zone': 'Time_Zone-str',
        'Vertical Datum': 'Vertical_Datum-str',
        'National Station ID': 'Station_ID-str',
        'Site Description': 'Site_Description-str',
        'Deployment': 'Deployment-str',
        'Deployment Position': 'Deployment_Postion-str',
        'Vertical Reference': 'Vertical_Reference-str'
    }, inplace=True)
    
    # Add new columns with default values
    combined_df['calc_SMD-f64'] = 0.0
    combined_df['mAHD-f64'] = 0.0
    
    # Convert Lat-f64 and Lon-f64 to UTM coordinates (XUTM-f64, YUTM-f64)
    in_proj = Proj('epsg:4326')  # WGS84 coordinates (Lat, Lon)
    out_proj = Proj('epsg:32732')  # UTM Zone 32N
    
    def convert_to_utm(lat, lon):
        x, y = transform(in_proj, out_proj, lon, lat)
        return x, y
    
    combined_df['XUTM-f64'], combined_df['YUTM-f64'] = zip(*combined_df.apply(lambda row: convert_to_utm(row['Lat-f64'], row['Lon-f64']), axis=1))

    # Rearrange columns as requested
    column_order = ['Agency-str', 'Agency_Code-str', 'Program_Name-str', 'Program_Code-str', 'Date-str', 'Data-f64', 'Depth-f64', 'Variable_ID-str', 'Variable_Name-str', 'Data_File_Name-str', 'Data_File_Location-str', 'Status-str', 'Lat-f64', 'Lon-f64', 'XUTM-f64', 'YUTM-f64', 'Time_Zone-str', 'Vertical_Datum-str', 'Station_ID-str', 'Site_Description-str', 'Deployment-str', 'Deployment_Postion-str', 'Vertical_Reference-str', 'calc_SMD-f64', 'mAHD-f64']
    combined_df = combined_df[column_order]
    
    return combined_df

def find_csv_header_files(directory):
    csv_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith("Header.csv"):
                csv_files.append(os.path.join(root, file))
    return csv_files

def find_csv_data_files(directory):
    csv_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith("Data.csv"):
                csv_files.append(os.path.join(root, file))
    return csv_files

directory = "../../data-warehouse/csv/ht/met"

header_files = find_csv_header_files(directory)
data_files = find_csv_data_files(directory)

# Match header files with corresponding data files
for header_file in header_files:
    # Construct the corresponding data file path
    data_file = header_file.replace("_Header.csv", "_Data.csv")
    
    # Ensure the data file exists before processing
    if data_file in data_files:
        combined_df = merge_header_and_data(header_file, data_file)
        print(f"Combined DataFrame for {header_file} and {data_file}:")
        print(combined_df.head())
        print()
    else:
        print(f"Data file not found for {header_file}")
# Out:
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/364662388.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# Combined DataFrame for ../../data-warehouse/csv/ht/met/BOMIDC_Precipitation_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOMIDC_Precipitation_profile_Data.csv:
#   Agency-str Agency_Code-str Program_Name-str Program_Code-str  \
# 0     HT-MET              HT              BOM              MET
# 1     HT-MET              HT              BOM              MET
# 2     HT-MET              HT              BOM              MET
# 3     HT-MET              HT              BOM              MET
# 4     HT-MET              HT              BOM              MET
#
#               Date-str  Data-f64  Depth-f64 Variable_ID-str Variable_Name-str  \
# 0  2000-01-01 00:00:00       NaN          0        var00152        IDCJAC0009
# 1  2000-01-02 00:00:00       NaN          0        var00152        IDCJAC0009
# 2  2000-01-03 00:00:00       NaN          0        var00152        IDCJAC0009
# 3  2000-01-04 00:00:00       NaN          0        var00152        IDCJAC0009
# 4  2000-01-05 00:00:00       NaN          0        var00152        IDCJAC0009
#
#   Data_File_Name-str  ... YUTM-f64 Time_Zone-str Vertical_Datum-str  \
# 0     IDCJAC0009.csv  ...      inf        GMT +6               mAHD
# 1     IDCJAC0009.csv  ...      inf        GMT +6               mAHD
# 2     IDCJAC0009.csv  ...      inf        GMT +6               mAHD
# 3     IDCJAC0009.csv  ...      inf        GMT +6               mAHD
# 4     IDCJAC0009.csv  ...      inf        GMT +6               mAHD
#
#   Station_ID-str  Site_Description-str  Deployment-str Deployment_Postion-str  \
# 0          96033                 96033         Profile         m from Surface
# 1          96033                 96033         Profile         m from Surface
# 2          96033                 96033         Profile         m from Surface
# 3          96033                 96033         Profile         m from Surface
# 4          96033                 96033         Profile         m from Surface
#
#   Vertical_Reference-str calc_SMD-f64 mAHD-f64
# 0          Water Surface          0.0      0.0
# 1          Water Surface          0.0      0.0
# 2          Water Surface          0.0      0.0
# 3          Water Surface          0.0      0.0
# 4          Water Surface          0.0      0.0
#
# [5 rows x 25 columns]
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/364662388.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# Combined DataFrame for ../../data-warehouse/csv/ht/met/BOM_WindDirection_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOM_WindDirection_profile_Data.csv:
#   Agency-str Agency_Code-str Program_Name-str Program_Code-str  \
# 0     HT-MET              HT              BOM              MET
# 1     HT-MET              HT              BOM              MET
# 2     HT-MET              HT              BOM              MET
# 3     HT-MET              HT              BOM              MET
# 4     HT-MET              HT              BOM              MET
#
#               Date-str  Data-f64  Depth-f64 Variable_ID-str Variable_Name-str  \
# 0  2011-07-14 14:00:00       NaN          0        var00129                WD
# 1  2011-07-14 15:00:00    225.00          0        var00129                WD
# 2  2011-07-14 16:00:00    236.25          0        var00129                WD
# 3  2011-07-14 17:00:00    236.25          0        var00129                WD
# 4  2011-07-14 18:00:00    236.25          0        var00129                WD
#
#   Data_File_Name-str  ... YUTM-f64 Time_Zone-str Vertical_Datum-str  \
# 0             WD.csv  ...      inf        GMT +6               mAHD
# 1             WD.csv  ...      inf        GMT +6               mAHD
# 2             WD.csv  ...      inf        GMT +6               mAHD
# 3             WD.csv  ...      inf        GMT +6               mAHD
# 4             WD.csv  ...      inf        GMT +6               mAHD
#
#   Station_ID-str  Site_Description-str  Deployment-str Deployment_Postion-str  \
# 0            462                   462         Profile         m from Surface
# 1            462                   462         Profile         m from Surface
# 2            462                   462         Profile         m from Surface
# 3            462                   462         Profile         m from Surface
# 4            462                   462         Profile         m from Surface
#
#   Vertical_Reference-str calc_SMD-f64 mAHD-f64
# 0          Water Surface          0.0      0.0
# 1          Water Surface          0.0      0.0
# 2          Water Surface          0.0      0.0
# 3          Water Surface          0.0      0.0
# 4          Water Surface          0.0      0.0
#
# [5 rows x 25 columns]
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/364662388.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = transform(in_proj, out_proj, lon, lat)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 99
#      97 # Ensure the data file exists before processing
#      98 if data_file in data_files:
# ---> 99     combined_df = merge_header_and_data(header_file, data_file)
#     100     print(f"Combined DataFrame for {header_file} and {data_file}:")
#     101     print(combined_df.head())
#
# Cell In[25], line 63, in merge_header_and_data(header_path, data_path)
#      60     x, y = transform(in_proj, out_proj, lon, lat)
#      61     return x, y
# ---> 63 combined_df['XUTM-f64'], combined_df['YUTM-f64'] = zip(*combined_df.apply(lambda row: convert_to_utm(row['Lat-f64'], row['Lon-f64']), axis=1))
#      65 # Rearrange columns as requested
#      66 column_order = ['Agency-str', 'Agency_Code-str', 'Program_Name-str', 'Program_Code-str', 'Date-str', 'Data-f64', 'Depth-f64', 'Variable_ID-str', 'Variable_Name-str', 'Data_File_Name-str', 'Data_File_Location-str', 'Status-str', 'Lat-f64', 'Lon-f64', 'XUTM-f64', 'YUTM-f64', 'Time_Zone-str', 'Vertical_Datum-str', 'Station_ID-str', 'Site_Description-str', 'Deployment-str', 'Deployment_Postion-str', 'Vertical_Reference-str', 'calc_SMD-f64', 'mAHD-f64']
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/frame.py:10037, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10025 from pandas.core.apply import frame_apply
#   10027 op = frame_apply(
#   10028     self,
#   10029     func=func,
#    (...)
#   10035     kwargs=kwargs,
#   10036 )
# > 10037 return op.apply().__finalize__(self, method="apply")
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/apply.py:837, in FrameApply.apply(self)
#     834 elif self.raw:
#     835     return self.apply_raw()
# --> 837 return self.apply_standard()
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/apply.py:963, in FrameApply.apply_standard(self)
#     962 def apply_standard(self):
# --> 963     results, res_index = self.apply_series_generator()
#     965     # wrap results
#     966     return self.wrap_results(results, res_index)
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/apply.py:979, in FrameApply.apply_series_generator(self)
#     976 with option_context("mode.chained_assignment", None):
#     977     for i, v in enumerate(series_gen):
#     978         # ignore SettingWithCopy here in case the user mutates
# --> 979         results[i] = self.func(v, *self.args, **self.kwargs)
#     980         if isinstance(results[i], ABCSeries):
#     981             # If we have a view on v, we need to make a copy because
#     982             #  series_generator will swap out the underlying data
#     983             results[i] = results[i].copy(deep=False)
#
# Cell In[25], line 63, in merge_header_and_data.<locals>.<lambda>(row)
#      60     x, y = transform(in_proj, out_proj, lon, lat)
#      61     return x, y
# ---> 63 combined_df['XUTM-f64'], combined_df['YUTM-f64'] = zip(*combined_df.apply(lambda row: convert_to_utm(row['Lat-f64'], row['Lon-f64']), axis=1))
#      65 # Rearrange columns as requested
#      66 column_order = ['Agency-str', 'Agency_Code-str', 'Program_Name-str', 'Program_Code-str', 'Date-str', 'Data-f64', 'Depth-f64', 'Variable_ID-str', 'Variable_Name-str', 'Data_File_Name-str', 'Data_File_Location-str', 'Status-str', 'Lat-f64', 'Lon-f64', 'XUTM-f64', 'YUTM-f64', 'Time_Zone-str', 'Vertical_Datum-str', 'Station_ID-str', 'Site_Description-str', 'Deployment-str', 'Deployment_Postion-str', 'Vertical_Reference-str', 'calc_SMD-f64', 'mAHD-f64']
#
# Cell In[25], line 60, in merge_header_and_data.<locals>.convert_to_utm(lat, lon)
#      59 def convert_to_utm(lat, lon):
# ---> 60     x, y = transform(in_proj, out_proj, lon, lat)
#      61     return x, y
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/transformer.py:1256, in transform(p1, p2, x, y, z, tt, radians, errcheck, always_xy)
#    1207 """
#    1208 .. versionadded:: 2.2.0 always_xy
#    1209
#    (...)
#    1245
#    1246 """
#    1247 warnings.warn(
#    1248     (
#    1249         "This function is deprecated. "
#    (...)
#    1254     stacklevel=2,
#    1255 )
# -> 1256 return Transformer.from_proj(p1, p2, always_xy=always_xy).transform(
#    1257     xx=x, yy=y, zz=z, tt=tt, radians=radians, errcheck=errcheck
#    1258 )
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/transformer.py:545, in Transformer.from_proj(proj_from, proj_to, always_xy, area_of_interest)
#     542 if not isinstance(proj_to, Proj):
#     543     proj_to = Proj(proj_to)
# --> 545 return Transformer.from_crs(
#     546     proj_from.crs,
#     547     proj_to.crs,
#     548     always_xy=always_xy,
#     549     area_of_interest=area_of_interest,
#     550 )
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/transformer.py:625, in Transformer.from_crs(crs_from, crs_to, always_xy, area_of_interest, authority, accuracy, allow_ballpark, force_over, only_best)
#     552 @staticmethod
#     553 def from_crs(
#     554     crs_from: Any,
#    (...)
#     562     only_best: Optional[bool] = None,
#     563 ) -> "Transformer":
#     564     """Make a Transformer from a :obj:`pyproj.crs.CRS` or input used to create one.
#     565
#     566     See:
#    (...)
#     623
#     624     """
# --> 625     return Transformer(
#     626         TransformerFromCRS(
#     627             cstrencode(CRS.from_user_input(crs_from).srs),
#     628             cstrencode(CRS.from_user_input(crs_to).srs),
#     629             always_xy=always_xy,
#     630             area_of_interest=area_of_interest,
#     631             authority=authority,
#     632             accuracy=accuracy if accuracy is None else str(accuracy),
#     633             allow_ballpark=allow_ballpark,
#     634             force_over=force_over,
#     635             only_best=only_best,
#     636         )
#     637     )
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/transformer.py:337, in Transformer.__init__(self, transformer_maker)
#     331     raise ProjError(
#     332         "Transformer must be initialized using: "
#     333         "'from_crs' or 'from_pipeline'."
#     334     )
#     336 self._local = TransformerLocal()
# --> 337 self._local.transformer = transformer_maker()
#     338 self._transformer_maker = transformer_maker
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pyproj/transformer.py:105, in TransformerFromCRS.__call__(self)
#      99 def __call__(self) -> _Transformer:
#     100     """
#     101     Returns
#     102     -------
#     103     _Transformer
#     104     """
# --> 105     return _Transformer.from_crs(
#     106         self.crs_from,
#     107         self.crs_to,
#     108         always_xy=self.always_xy,
#     109         area_of_interest=self.area_of_interest,
#     110         authority=self.authority,
#     111         accuracy=self.accuracy,
#     112         allow_ballpark=self.allow_ballpark,
#     113         force_over=self.force_over,
#     114         only_best=self.only_best,
#     115     )
#
# KeyboardInterrupt:

# %%
import os
import pandas as pd
import pyproj

def csv_to_single_row_dataframe(file_path):
    # Read the CSV file
    df = pd.read_csv(file_path)
    
    # Use the first column as headers and the second column as row values
    single_row_df = pd.DataFrame([df.iloc[:, 1].values], columns=df.iloc[:, 0].values)
    
    return single_row_df

def merge_header_and_data(header_path, data_path):
    header_df = csv_to_single_row_dataframe(header_path)
    selected_columns = ['Agency Code', 'Program', 'Project', 'Tag', 'Data File Name', 'Location', 'Station Status', 'Lat', 'Long', 'Time Zone', 'Vertical Datum', 'National Station ID', 'Site Description', 'Deployment', 'Deployment Position', 'Vertical Reference', 'Variable ID']
    header_df = header_df[selected_columns]
    data_df = pd.read_csv(data_path)
    
    # Repeat the header for each row in the data DataFrame
    header_repeated = pd.concat([header_df] * len(data_df), ignore_index=True)
    
    # Combine the header and data DataFrames
    combined_df = pd.concat([header_repeated, data_df], axis=1)
    
    # Rename columns as requested
    combined_df.rename(columns={
        'Tag': 'Agency-str',
        'Agency Code': 'Agency_Code-str',
        'Program': 'Program_Name-str',
        'Project': 'Program_Code-str',
        'Date': 'Date-str',
        'Data': 'Data-f64',
        'Depth': 'Depth-f64',
        'Variable ID': 'Variable_ID-str',
        'Variable': 'Variable_Name-str',
        'Data File Name': 'Data_File_Name-str',
        'Location': 'Data_File_Location-str',
        'Station Status': 'Status-str',
        'Lat': 'Lat-f64',
        'Long': 'Lon-f64',
        'Time Zone': 'Time_Zone-str',
        'Vertical Datum': 'Vertical_Datum-str',
        'National Station ID': 'Station_ID-str',
        'Site Description': 'Site_Description-str',
        'Deployment': 'Deployment-str',
        'Deployment Position': 'Deployment_Postion-str',
        'Vertical Reference': 'Vertical_Reference-str'
    }, inplace=True)
    
    # Add new columns with default values
    combined_df['calc_SMD-f64'] = 0.0
    combined_df['mAHD-f64'] = 0.0
    
    # Convert Lat-f64 and Lon-f64 to UTM coordinates (XUTM-f64, YUTM-f64)
    from pyproj import Proj, transform
    in_proj = Proj('epsg:4326')  # WGS84 coordinates (Lat, Lon)
    out_proj = Proj('epsg:32732')  # UTM Zone 32N
    
    combined_df['XUTM-f64'], combined_df['YUTM-f64'] = transform(in_proj, out_proj, combined_df['Lon-f64'].values, combined_df['Lat-f64'].values)

    # Rearrange columns as requested
    column_order = ['Agency-str', 'Agency_Code-str', 'Program_Name-str', 'Program_Code-str', 'Date-str', 'Data-f64', 'Depth-f64', 'Variable_ID-str', 'Variable_Name-str', 'Data_File_Name-str', 'Data_File_Location-str', 'Status-str', 'Lat-f64', 'Lon-f64', 'XUTM-f64', 'YUTM-f64', 'Time_Zone-str', 'Vertical_Datum-str', 'Station_ID-str', 'Site_Description-str', 'Deployment-str', 'Deployment_Postion-str', 'Vertical_Reference-str', 'calc_SMD-f64', 'mAHD-f64']
    combined_df = combined_df[column_order]
    
    return combined_df

def find_csv_header_files(directory):
    csv_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith("Header.csv"):
                csv_files.append(os.path.join(root, file))
    return csv_files

def find_csv_data_files(directory):
    csv_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith("Data.csv"):
                csv_files.append(os.path.join(root, file))
    return csv_files

directory = "../../data-warehouse/csv/ht/met"

header_files = find_csv_header_files(directory)
data_files = find_csv_data_files(directory)

# Match header files with corresponding data files
for header_file in header_files:
    # Construct the corresponding data file path
    data_file = header_file.replace("_Header.csv", "_Data.csv")
    
    # Ensure the data file exists before processing
    if data_file in data_files:
        combined_df = merge_header_and_data(header_file, data_file)
        print(f"Combined DataFrame for {header_file} and {data_file}:")
        print(combined_df.head())
        print()
    else:
        print(f"Data file not found for {header_file}")
# Out:
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/4011885052.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   combined_df['XUTM-f64'], combined_df['YUTM-f64'] = transform(in_proj, out_proj, combined_df['Lon-f64'].values, combined_df['Lat-f64'].values)
# Combined DataFrame for ../../data-warehouse/csv/ht/met/BOMIDC_Precipitation_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOMIDC_Precipitation_profile_Data.csv:
#   Agency-str Agency_Code-str Program_Name-str Program_Code-str  \
# 0     HT-MET              HT              BOM              MET
# 1     HT-MET              HT              BOM              MET
# 2     HT-MET              HT              BOM              MET
# 3     HT-MET              HT              BOM              MET
# 4     HT-MET              HT              BOM              MET
#
#               Date-str  Data-f64  Depth-f64 Variable_ID-str Variable_Name-str  \
# 0  2000-01-01 00:00:00       NaN          0        var00152        IDCJAC0009
# 1  2000-01-02 00:00:00       NaN          0        var00152        IDCJAC0009
# 2  2000-01-03 00:00:00       NaN          0        var00152        IDCJAC0009
# 3  2000-01-04 00:00:00       NaN          0        var00152        IDCJAC0009
# 4  2000-01-05 00:00:00       NaN          0        var00152        IDCJAC0009
#
#   Data_File_Name-str  ... YUTM-f64 Time_Zone-str Vertical_Datum-str  \
# 0     IDCJAC0009.csv  ...      inf        GMT +6               mAHD
# 1     IDCJAC0009.csv  ...      inf        GMT +6               mAHD
# 2     IDCJAC0009.csv  ...      inf        GMT +6               mAHD
# 3     IDCJAC0009.csv  ...      inf        GMT +6               mAHD
# 4     IDCJAC0009.csv  ...      inf        GMT +6               mAHD
#
#   Station_ID-str  Site_Description-str  Deployment-str Deployment_Postion-str  \
# 0          96033                 96033         Profile         m from Surface
# 1          96033                 96033         Profile         m from Surface
# 2          96033                 96033         Profile         m from Surface
# 3          96033                 96033         Profile         m from Surface
# 4          96033                 96033         Profile         m from Surface
#
#   Vertical_Reference-str calc_SMD-f64 mAHD-f64
# 0          Water Surface          0.0      0.0
# 1          Water Surface          0.0      0.0
# 2          Water Surface          0.0      0.0
# 3          Water Surface          0.0      0.0
# 4          Water Surface          0.0      0.0
#
# [5 rows x 25 columns]
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/4011885052.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   combined_df['XUTM-f64'], combined_df['YUTM-f64'] = transform(in_proj, out_proj, combined_df['Lon-f64'].values, combined_df['Lat-f64'].values)
# Combined DataFrame for ../../data-warehouse/csv/ht/met/BOM_WindDirection_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOM_WindDirection_profile_Data.csv:
#   Agency-str Agency_Code-str Program_Name-str Program_Code-str  \
# 0     HT-MET              HT              BOM              MET
# 1     HT-MET              HT              BOM              MET
# 2     HT-MET              HT              BOM              MET
# 3     HT-MET              HT              BOM              MET
# 4     HT-MET              HT              BOM              MET
#
#               Date-str  Data-f64  Depth-f64 Variable_ID-str Variable_Name-str  \
# 0  2011-07-14 14:00:00       NaN          0        var00129                WD
# 1  2011-07-14 15:00:00    225.00          0        var00129                WD
# 2  2011-07-14 16:00:00    236.25          0        var00129                WD
# 3  2011-07-14 17:00:00    236.25          0        var00129                WD
# 4  2011-07-14 18:00:00    236.25          0        var00129                WD
#
#   Data_File_Name-str  ... YUTM-f64 Time_Zone-str Vertical_Datum-str  \
# 0             WD.csv  ...      inf        GMT +6               mAHD
# 1             WD.csv  ...      inf        GMT +6               mAHD
# 2             WD.csv  ...      inf        GMT +6               mAHD
# 3             WD.csv  ...      inf        GMT +6               mAHD
# 4             WD.csv  ...      inf        GMT +6               mAHD
#
#   Station_ID-str  Site_Description-str  Deployment-str Deployment_Postion-str  \
# 0            462                   462         Profile         m from Surface
# 1            462                   462         Profile         m from Surface
# 2            462                   462         Profile         m from Surface
# 3            462                   462         Profile         m from Surface
# 4            462                   462         Profile         m from Surface
#
#   Vertical_Reference-str calc_SMD-f64 mAHD-f64
# 0          Water Surface          0.0      0.0
# 1          Water Surface          0.0      0.0
# 2          Water Surface          0.0      0.0
# 3          Water Surface          0.0      0.0
# 4          Water Surface          0.0      0.0
#
# [5 rows x 25 columns]
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/4011885052.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   combined_df['XUTM-f64'], combined_df['YUTM-f64'] = transform(in_proj, out_proj, combined_df['Lon-f64'].values, combined_df['Lat-f64'].values)
# Combined DataFrame for ../../data-warehouse/csv/ht/met/BOM_AirTemperature_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOM_AirTemperature_profile_Data.csv:
#   Agency-str Agency_Code-str Program_Name-str Program_Code-str  \
# 0     HT-MET              HT              BOM              MET
# 1     HT-MET              HT              BOM              MET
# 2     HT-MET              HT              BOM              MET
# 3     HT-MET              HT              BOM              MET
# 4     HT-MET              HT              BOM              MET
#
#               Date-str  Data-f64  Depth-f64 Variable_ID-str Variable_Name-str  \
# 0  2011-07-14 14:00:00       NaN          0        var00153           AirTemp
# 1  2011-07-14 15:00:00     1.550          0        var00153           AirTemp
# 2  2011-07-14 16:00:00     1.050          0        var00153           AirTemp
# 3  2011-07-14 17:00:00     0.475          0        var00153           AirTemp
# 4  2011-07-14 18:00:00     0.125          0        var00153           AirTemp
#
#   Data_File_Name-str  ... YUTM-f64 Time_Zone-str Vertical_Datum-str  \
# 0        AirTemp.csv  ...      inf        GMT +6               mAHD
# 1        AirTemp.csv  ...      inf        GMT +6               mAHD
# 2        AirTemp.csv  ...      inf        GMT +6               mAHD
# 3        AirTemp.csv  ...      inf        GMT +6               mAHD
# 4        AirTemp.csv  ...      inf        GMT +6               mAHD
#
#   Station_ID-str  Site_Description-str  Deployment-str Deployment_Postion-str  \
# 0            462                   462         Profile         m from Surface
# 1            462                   462         Profile         m from Surface
# 2            462                   462         Profile         m from Surface
# 3            462                   462         Profile         m from Surface
# 4            462                   462         Profile         m from Surface
#
#   Vertical_Reference-str calc_SMD-f64 mAHD-f64
# 0          Water Surface          0.0      0.0
# 1          Water Surface          0.0      0.0
# 2          Water Surface          0.0      0.0
# 3          Water Surface          0.0      0.0
# 4          Water Surface          0.0      0.0
#
# [5 rows x 25 columns]
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/4011885052.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   combined_df['XUTM-f64'], combined_df['YUTM-f64'] = transform(in_proj, out_proj, combined_df['Lon-f64'].values, combined_df['Lat-f64'].values)
# Combined DataFrame for ../../data-warehouse/csv/ht/met/BOM_RelativeHumidity_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOM_RelativeHumidity_profile_Data.csv:
#   Agency-str Agency_Code-str Program_Name-str Program_Code-str  \
# 0     HT-MET              HT              BOM              MET
# 1     HT-MET              HT              BOM              MET
# 2     HT-MET              HT              BOM              MET
# 3     HT-MET              HT              BOM              MET
# 4     HT-MET              HT              BOM              MET
#
#               Date-str  Data-f64  Depth-f64 Variable_ID-str Variable_Name-str  \
# 0  2011-07-14 14:00:00       NaN          0        var00156          Humidity
# 1  2011-07-14 15:00:00       NaN          0        var00156          Humidity
# 2  2011-07-14 16:00:00       NaN          0        var00156          Humidity
# 3  2011-07-14 17:00:00       NaN          0        var00156          Humidity
# 4  2011-07-14 18:00:00       NaN          0        var00156          Humidity
#
#   Data_File_Name-str  ... YUTM-f64 Time_Zone-str Vertical_Datum-str  \
# 0       Humidity.csv  ...      inf        GMT +6               mAHD
# 1       Humidity.csv  ...      inf        GMT +6               mAHD
# 2       Humidity.csv  ...      inf        GMT +6               mAHD
# 3       Humidity.csv  ...      inf        GMT +6               mAHD
# 4       Humidity.csv  ...      inf        GMT +6               mAHD
#
#   Station_ID-str  Site_Description-str  Deployment-str Deployment_Postion-str  \
# 0            462                   462         Profile         m from Surface
# 1            462                   462         Profile         m from Surface
# 2            462                   462         Profile         m from Surface
# 3            462                   462         Profile         m from Surface
# 4            462                   462         Profile         m from Surface
#
#   Vertical_Reference-str calc_SMD-f64 mAHD-f64
# 0          Water Surface          0.0      0.0
# 1          Water Surface          0.0      0.0
# 2          Water Surface          0.0      0.0
# 3          Water Surface          0.0      0.0
# 4          Water Surface          0.0      0.0
#
# [5 rows x 25 columns]
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/4011885052.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   combined_df['XUTM-f64'], combined_df['YUTM-f64'] = transform(in_proj, out_proj, combined_df['Lon-f64'].values, combined_df['Lat-f64'].values)
# Combined DataFrame for ../../data-warehouse/csv/ht/met/BOM_Precipitation_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOM_Precipitation_profile_Data.csv:
#   Agency-str Agency_Code-str Program_Name-str Program_Code-str  \
# 0     HT-MET              HT              BOM              MET
# 1     HT-MET              HT              BOM              MET
# 2     HT-MET              HT              BOM              MET
# 3     HT-MET              HT              BOM              MET
# 4     HT-MET              HT              BOM              MET
#
#               Date-str  Data-f64  Depth-f64 Variable_ID-str Variable_Name-str  \
# 0  2011-07-15 10:00:00       NaN          0        var00152          Rainfall
# 1  2011-07-15 11:00:00       0.0          0        var00152          Rainfall
# 2  2011-07-15 12:00:00       0.0          0        var00152          Rainfall
# 3  2011-07-15 13:00:00       0.0          0        var00152          Rainfall
# 4  2011-07-15 14:00:00       0.0          0        var00152          Rainfall
#
#   Data_File_Name-str  ... YUTM-f64 Time_Zone-str Vertical_Datum-str  \
# 0     IDCJAC0009.csv  ...      inf        GMT +6               mAHD
# 1     IDCJAC0009.csv  ...      inf        GMT +6               mAHD
# 2     IDCJAC0009.csv  ...      inf        GMT +6               mAHD
# 3     IDCJAC0009.csv  ...      inf        GMT +6               mAHD
# 4     IDCJAC0009.csv  ...      inf        GMT +6               mAHD
#
#   Station_ID-str  Site_Description-str  Deployment-str Deployment_Postion-str  \
# 0            462                   462         Profile         m from Surface
# 1            462                   462         Profile         m from Surface
# 2            462                   462         Profile         m from Surface
# 3            462                   462         Profile         m from Surface
# 4            462                   462         Profile         m from Surface
#
#   Vertical_Reference-str calc_SMD-f64 mAHD-f64
# 0          Water Surface          0.0      0.0
# 1          Water Surface          0.0      0.0
# 2          Water Surface          0.0      0.0
# 3          Water Surface          0.0      0.0
# 4          Water Surface          0.0      0.0
#
# [5 rows x 25 columns]
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/4011885052.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   combined_df['XUTM-f64'], combined_df['YUTM-f64'] = transform(in_proj, out_proj, combined_df['Lon-f64'].values, combined_df['Lat-f64'].values)
# Combined DataFrame for ../../data-warehouse/csv/ht/met/BOM_WindSpeed_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOM_WindSpeed_profile_Data.csv:
#   Agency-str Agency_Code-str Program_Name-str Program_Code-str  \
# 0     HT-MET              HT              BOM              MET
# 1     HT-MET              HT              BOM              MET
# 2     HT-MET              HT              BOM              MET
# 3     HT-MET              HT              BOM              MET
# 4     HT-MET              HT              BOM              MET
#
#               Date-str  Data-f64  Depth-f64 Variable_ID-str Variable_Name-str  \
# 0  2011-07-14 14:00:00       NaN          0        var00130                WS
# 1  2011-07-14 15:00:00      6.02          0        var00130                WS
# 2  2011-07-14 16:00:00      5.67          0        var00130                WS
# 3  2011-07-14 17:00:00      4.06          0        var00130                WS
# 4  2011-07-14 18:00:00      4.62          0        var00130                WS
#
#   Data_File_Name-str  ... YUTM-f64 Time_Zone-str Vertical_Datum-str  \
# 0             WS.csv  ...      inf        GMT +6               mAHD
# 1             WS.csv  ...      inf        GMT +6               mAHD
# 2             WS.csv  ...      inf        GMT +6               mAHD
# 3             WS.csv  ...      inf        GMT +6               mAHD
# 4             WS.csv  ...      inf        GMT +6               mAHD
#
#   Station_ID-str  Site_Description-str  Deployment-str Deployment_Postion-str  \
# 0            462                   462         Profile         m from Surface
# 1            462                   462         Profile         m from Surface
# 2            462                   462         Profile         m from Surface
# 3            462                   462         Profile         m from Surface
# 4            462                   462         Profile         m from Surface
#
#   Vertical_Reference-str calc_SMD-f64 mAHD-f64
# 0          Water Surface          0.0      0.0
# 1          Water Surface          0.0      0.0
# 2          Water Surface          0.0      0.0
# 3          Water Surface          0.0      0.0
# 4          Water Surface          0.0      0.0
#
# [5 rows x 25 columns]
#
# Combined DataFrame for ../../data-warehouse/csv/ht/met/WoodsLakeAtDam_Precipitation_profile_Header.csv and ../../data-warehouse/csv/ht/met/WoodsLakeAtDam_Precipitation_profile_Data.csv:
#   Agency-str Agency_Code-str Program_Name-str Program_Code-str  \
# 0     HT-MET              HT       Woods Lake              MET
# 1     HT-MET              HT       Woods Lake              MET
# 2     HT-MET              HT       Woods Lake              MET
# 3     HT-MET              HT       Woods Lake              MET
# 4     HT-MET              HT       Woods Lake              MET
#
#               Date-str  Data-f64  Depth-f64 Variable_ID-str Variable_Name-str  \
# 0  2015-01-01 01:00:00       0.0          0        var00152          Rainfall
# 1  2015-01-01 02:00:00       0.0          0        var00152          Rainfall
# 2  2015-01-01 03:00:00       0.0          0        var00152          Rainfall
# 3  2015-01-01 04:00:00       0.0          0        var00152          Rainfall
# 4  2015-01-01 05:00:00       0.0          0        var00152          Rainfall
#
#   Data_File_Name-str  ... YUTM-f64 Time_Zone-str Vertical_Datum-str  \
# 0       Rainfall.csv  ...      inf        GMT +6               mAHD
# 1       Rainfall.csv  ...      inf        GMT +6               mAHD
# 2       Rainfall.csv  ...      inf        GMT +6               mAHD
# 3       Rainfall.csv  ...      inf        GMT +6               mAHD
# 4       Rainfall.csv  ...      inf        GMT +6               mAHD
#
#   Station_ID-str  Site_Description-str  Deployment-str Deployment_Postion-str  \
# 0            462                   462         Profile         m from Surface
# 1            462                   462         Profile         m from Surface
# 2            462                   462         Profile         m from Surface
# 3            462                   462         Profile         m from Surface
# 4            462                   462         Profile         m from Surface
#
#   Vertical_Reference-str calc_SMD-f64 mAHD-f64
# 0          Water Surface          0.0      0.0
# 1          Water Surface          0.0      0.0
# 2          Water Surface          0.0      0.0
# 3          Water Surface          0.0      0.0
# 4          Water Surface          0.0      0.0
#
# [5 rows x 25 columns]
# /var/folders/bw/k9zj3x2s7fj89p6_lfwvpc440000gn/T/ipykernel_82552/4011885052.py:60: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   combined_df['XUTM-f64'], combined_df['YUTM-f64'] = transform(in_proj, out_proj, combined_df['Lon-f64'].values, combined_df['Lat-f64'].values)

# %%
import os
import pandas as pd

def csv_to_single_row_dataframe(file_path):
    # Read the CSV file
    df = pd.read_csv(file_path)
    
    # Use the first column as headers and the second column as row values
    single_row_df = pd.DataFrame([df.iloc[:, 1].values], columns=df.iloc[:, 0].values)
    
    return single_row_df

def merge_header_and_data(header_path, data_path):
    header_df = csv_to_single_row_dataframe(header_path)
    selected_columns = ['Agency Code', 'Program', 'Project', 'Tag', 'Data File Name', 'Location', 'Station Status', 'Lat', 'Long', 'Time Zone', 'Vertical Datum', 'National Station ID', 'Site Description', 'Deployment', 'Deployment Position', 'Vertical Reference', 'Variable ID']
    header_df = header_df[selected_columns]
    data_df = pd.read_csv(data_path)
    
    # Repeat the header for each row in the data DataFrame
    header_repeated = pd.concat([header_df] * len(data_df), ignore_index=True)
    
    # Combine the header and data DataFrames
    combined_df = pd.concat([header_repeated, data_df], axis=1)

    # Rearrange columns as requested
    column_order = ['Tag', 'Agency Code', 'Program', 'Project', 'Date', 'Data', 'Depth', 'Variable ID', 'Variable', 'Data File Name', 'Location', 'Station Status', 'Lat', 'Long', 'Time Zone', 'Vertical Datum', 'National Station ID', 'Site Description', 'Deployment', 'Deployment Position', 'Vertical Reference']
    combined_df = combined_df[column_order]
    
    # Rename columns as requested
    combined_df.rename(columns={
        'Tag': 'Agency-str',
        'Agency Code': 'Agency_Code-str',
        'Program': 'Program_Name-str',
        'Project': 'Program_Code-str',
        'Date': 'Date-str',
        'Data': 'Data-f64',
        'Depth': 'Depth-f64',
        'Variable ID': 'Variable_ID-str',
        'Variable': 'Variable_Name-str',
        'Data File Name': 'Data_File_Name-str',
        'Location': 'Data_File_Location-str',
        'Station Status': 'Status-str',
        'Lat': 'Lat-f64',
        'Long': 'Lon-f64',
        'Time Zone': 'Time_Zone-str',
        'Vertical Datum': 'Vertical_Datum-str',
        'National Station ID': 'Station_ID-str',
        'Site Description': 'Site_Description-str',
        'Deployment': 'Deployment-str',
        'Deployment Position': 'Deployment_Postion-str',
        'Vertical Reference': 'Vertical_Reference-str'
    }, inplace=True)
    
    return combined_df

def find_csv_header_files(directory):
    csv_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith("Header.csv"):
                csv_files.append(os.path.join(root, file))
    return csv_files

def find_csv_data_files(directory):
    csv_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith("Data.csv"):
                csv_files.append(os.path.join(root, file))
    return csv_files

directory = "../../data-warehouse/csv/ht/met"

header_files = find_csv_header_files(directory)
data_files = find_csv_data_files(directory)

# Match header files with corresponding data files
for header_file in header_files:
    # Construct the corresponding data file path
    data_file = header_file.replace("_Header.csv", "_Data.csv")
    
    # Ensure the data file exists before processing
    if data_file in data_files:
        combined_df = merge_header_and_data(header_file, data_file)
        print(f"Combined DataFrame for {header_file} and {data_file}:")
        print(combined_df.head())
        print()
    else:
        print(f"Data file not found for {header_file}")
# Out:
# Combined DataFrame for ../../data-warehouse/csv/ht/met/BOMIDC_Precipitation_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOMIDC_Precipitation_profile_Data.csv:
#   Agency-str Agency_Code-str Program_Name-str Program_Code-str  \
# 0     HT-MET              HT              BOM              MET
# 1     HT-MET              HT              BOM              MET
# 2     HT-MET              HT              BOM              MET
# 3     HT-MET              HT              BOM              MET
# 4     HT-MET              HT              BOM              MET
#
#               Date-str  Data-f64  Depth-f64 Variable_ID-str Variable_Name-str  \
# 0  2000-01-01 00:00:00       NaN          0        var00152        IDCJAC0009
# 1  2000-01-02 00:00:00       NaN          0        var00152        IDCJAC0009
# 2  2000-01-03 00:00:00       NaN          0        var00152        IDCJAC0009
# 3  2000-01-04 00:00:00       NaN          0        var00152        IDCJAC0009
# 4  2000-01-05 00:00:00       NaN          0        var00152        IDCJAC0009
#
#   Data_File_Name-str  ... Status-str Lat-f64 Lon-f64 Time_Zone-str  \
# 0     IDCJAC0009.csv  ...     Active  -41.90  146.67        GMT +6
# 1     IDCJAC0009.csv  ...     Active  -41.90  146.67        GMT +6
# 2     IDCJAC0009.csv  ...     Active  -41.90  146.67        GMT +6
# 3     IDCJAC0009.csv  ...     Active  -41.90  146.67        GMT +6
# 4     IDCJAC0009.csv  ...     Active  -41.90  146.67        GMT +6
#
#   Vertical_Datum-str Station_ID-str Site_Description-str Deployment-str  \
# 0               mAHD          96033                96033        Profile
# 1               mAHD          96033                96033        Profile
# 2               mAHD          96033                96033        Profile
# 3               mAHD          96033                96033        Profile
# 4               mAHD          96033                96033        Profile
#
#   Deployment_Postion-str Vertical_Reference-str
# 0         m from Surface          Water Surface
# 1         m from Surface          Water Surface
# 2         m from Surface          Water Surface
# 3         m from Surface          Water Surface
# 4         m from Surface          Water Surface
#
# [5 rows x 21 columns]
#
# Combined DataFrame for ../../data-warehouse/csv/ht/met/BOM_WindDirection_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOM_WindDirection_profile_Data.csv:
#   Agency-str Agency_Code-str Program_Name-str Program_Code-str  \
# 0     HT-MET              HT              BOM              MET
# 1     HT-MET              HT              BOM              MET
# 2     HT-MET              HT              BOM              MET
# 3     HT-MET              HT              BOM              MET
# 4     HT-MET              HT              BOM              MET
#
#               Date-str  Data-f64  Depth-f64 Variable_ID-str Variable_Name-str  \
# 0  2011-07-14 14:00:00       NaN          0        var00129                WD
# 1  2011-07-14 15:00:00    225.00          0        var00129                WD
# 2  2011-07-14 16:00:00    236.25          0        var00129                WD
# 3  2011-07-14 17:00:00    236.25          0        var00129                WD
# 4  2011-07-14 18:00:00    236.25          0        var00129                WD
#
#   Data_File_Name-str  ... Status-str     Lat-f64     Lon-f64 Time_Zone-str  \
# 0             WD.csv  ...     Active  -42.080562  147.004210        GMT +6
# 1             WD.csv  ...     Active  -42.080562  147.004210        GMT +6
# 2             WD.csv  ...     Active  -42.080562  147.004210        GMT +6
# 3             WD.csv  ...     Active  -42.080562  147.004210        GMT +6
# 4             WD.csv  ...     Active  -42.080562  147.004210        GMT +6
#
#   Vertical_Datum-str Station_ID-str Site_Description-str Deployment-str  \
# 0               mAHD            462                  462        Profile
# 1               mAHD            462                  462        Profile
# 2               mAHD            462                  462        Profile
# 3               mAHD            462                  462        Profile
# 4               mAHD            462                  462        Profile
#
#   Deployment_Postion-str Vertical_Reference-str
# 0         m from Surface          Water Surface
# 1         m from Surface          Water Surface
# 2         m from Surface          Water Surface
# 3         m from Surface          Water Surface
# 4         m from Surface          Water Surface
#
# [5 rows x 21 columns]
#
# Combined DataFrame for ../../data-warehouse/csv/ht/met/BOM_AirTemperature_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOM_AirTemperature_profile_Data.csv:
#   Agency-str Agency_Code-str Program_Name-str Program_Code-str  \
# 0     HT-MET              HT              BOM              MET
# 1     HT-MET              HT              BOM              MET
# 2     HT-MET              HT              BOM              MET
# 3     HT-MET              HT              BOM              MET
# 4     HT-MET              HT              BOM              MET
#
#               Date-str  Data-f64  Depth-f64 Variable_ID-str Variable_Name-str  \
# 0  2011-07-14 14:00:00       NaN          0        var00153           AirTemp
# 1  2011-07-14 15:00:00     1.550          0        var00153           AirTemp
# 2  2011-07-14 16:00:00     1.050          0        var00153           AirTemp
# 3  2011-07-14 17:00:00     0.475          0        var00153           AirTemp
# 4  2011-07-14 18:00:00     0.125          0        var00153           AirTemp
#
#   Data_File_Name-str  ... Status-str     Lat-f64     Lon-f64 Time_Zone-str  \
# 0        AirTemp.csv  ...     Active  -42.080562  147.004210        GMT +6
# 1        AirTemp.csv  ...     Active  -42.080562  147.004210        GMT +6
# 2        AirTemp.csv  ...     Active  -42.080562  147.004210        GMT +6
# 3        AirTemp.csv  ...     Active  -42.080562  147.004210        GMT +6
# 4        AirTemp.csv  ...     Active  -42.080562  147.004210        GMT +6
#
#   Vertical_Datum-str Station_ID-str Site_Description-str Deployment-str  \
# 0               mAHD            462                  462        Profile
# 1               mAHD            462                  462        Profile
# 2               mAHD            462                  462        Profile
# 3               mAHD            462                  462        Profile
# 4               mAHD            462                  462        Profile
#
#   Deployment_Postion-str Vertical_Reference-str
# 0         m from Surface          Water Surface
# 1         m from Surface          Water Surface
# 2         m from Surface          Water Surface
# 3         m from Surface          Water Surface
# 4         m from Surface          Water Surface
#
# [5 rows x 21 columns]
#
# Combined DataFrame for ../../data-warehouse/csv/ht/met/BOM_RelativeHumidity_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOM_RelativeHumidity_profile_Data.csv:
#   Agency-str Agency_Code-str Program_Name-str Program_Code-str  \
# 0     HT-MET              HT              BOM              MET
# 1     HT-MET              HT              BOM              MET
# 2     HT-MET              HT              BOM              MET
# 3     HT-MET              HT              BOM              MET
# 4     HT-MET              HT              BOM              MET
#
#               Date-str  Data-f64  Depth-f64 Variable_ID-str Variable_Name-str  \
# 0  2011-07-14 14:00:00       NaN          0        var00156          Humidity
# 1  2011-07-14 15:00:00       NaN          0        var00156          Humidity
# 2  2011-07-14 16:00:00       NaN          0        var00156          Humidity
# 3  2011-07-14 17:00:00       NaN          0        var00156          Humidity
# 4  2011-07-14 18:00:00       NaN          0        var00156          Humidity
#
#   Data_File_Name-str  ... Status-str     Lat-f64     Lon-f64 Time_Zone-str  \
# 0       Humidity.csv  ...     Active  -42.080562  147.004210        GMT +6
# 1       Humidity.csv  ...     Active  -42.080562  147.004210        GMT +6
# 2       Humidity.csv  ...     Active  -42.080562  147.004210        GMT +6
# 3       Humidity.csv  ...     Active  -42.080562  147.004210        GMT +6
# 4       Humidity.csv  ...     Active  -42.080562  147.004210        GMT +6
#
#   Vertical_Datum-str Station_ID-str Site_Description-str Deployment-str  \
# 0               mAHD            462                  462        Profile
# 1               mAHD            462                  462        Profile
# 2               mAHD            462                  462        Profile
# 3               mAHD            462                  462        Profile
# 4               mAHD            462                  462        Profile
#
#   Deployment_Postion-str Vertical_Reference-str
# 0         m from Surface          Water Surface
# 1         m from Surface          Water Surface
# 2         m from Surface          Water Surface
# 3         m from Surface          Water Surface
# 4         m from Surface          Water Surface
#
# [5 rows x 21 columns]
#
# Combined DataFrame for ../../data-warehouse/csv/ht/met/BOM_Precipitation_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOM_Precipitation_profile_Data.csv:
#   Agency-str Agency_Code-str Program_Name-str Program_Code-str  \
# 0     HT-MET              HT              BOM              MET
# 1     HT-MET              HT              BOM              MET
# 2     HT-MET              HT              BOM              MET
# 3     HT-MET              HT              BOM              MET
# 4     HT-MET              HT              BOM              MET
#
#               Date-str  Data-f64  Depth-f64 Variable_ID-str Variable_Name-str  \
# 0  2011-07-15 10:00:00       NaN          0        var00152          Rainfall
# 1  2011-07-15 11:00:00       0.0          0        var00152          Rainfall
# 2  2011-07-15 12:00:00       0.0          0        var00152          Rainfall
# 3  2011-07-15 13:00:00       0.0          0        var00152          Rainfall
# 4  2011-07-15 14:00:00       0.0          0        var00152          Rainfall
#
#   Data_File_Name-str  ... Status-str     Lat-f64     Lon-f64 Time_Zone-str  \
# 0     IDCJAC0009.csv  ...     Active  -42.080562  147.004210        GMT +6
# 1     IDCJAC0009.csv  ...     Active  -42.080562  147.004210        GMT +6
# 2     IDCJAC0009.csv  ...     Active  -42.080562  147.004210        GMT +6
# 3     IDCJAC0009.csv  ...     Active  -42.080562  147.004210        GMT +6
# 4     IDCJAC0009.csv  ...     Active  -42.080562  147.004210        GMT +6
#
#   Vertical_Datum-str Station_ID-str Site_Description-str Deployment-str  \
# 0               mAHD            462                  462        Profile
# 1               mAHD            462                  462        Profile
# 2               mAHD            462                  462        Profile
# 3               mAHD            462                  462        Profile
# 4               mAHD            462                  462        Profile
#
#   Deployment_Postion-str Vertical_Reference-str
# 0         m from Surface          Water Surface
# 1         m from Surface          Water Surface
# 2         m from Surface          Water Surface
# 3         m from Surface          Water Surface
# 4         m from Surface          Water Surface
#
# [5 rows x 21 columns]
#
# Combined DataFrame for ../../data-warehouse/csv/ht/met/BOM_WindSpeed_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOM_WindSpeed_profile_Data.csv:
#   Agency-str Agency_Code-str Program_Name-str Program_Code-str  \
# 0     HT-MET              HT              BOM              MET
# 1     HT-MET              HT              BOM              MET
# 2     HT-MET              HT              BOM              MET
# 3     HT-MET              HT              BOM              MET
# 4     HT-MET              HT              BOM              MET
#
#               Date-str  Data-f64  Depth-f64 Variable_ID-str Variable_Name-str  \
# 0  2011-07-14 14:00:00       NaN          0        var00130                WS
# 1  2011-07-14 15:00:00      6.02          0        var00130                WS
# 2  2011-07-14 16:00:00      5.67          0        var00130                WS
# 3  2011-07-14 17:00:00      4.06          0        var00130                WS
# 4  2011-07-14 18:00:00      4.62          0        var00130                WS
#
#   Data_File_Name-str  ... Status-str     Lat-f64     Lon-f64 Time_Zone-str  \
# 0             WS.csv  ...     Active  -42.080562  147.004210        GMT +6
# 1             WS.csv  ...     Active  -42.080562  147.004210        GMT +6
# 2             WS.csv  ...     Active  -42.080562  147.004210        GMT +6
# 3             WS.csv  ...     Active  -42.080562  147.004210        GMT +6
# 4             WS.csv  ...     Active  -42.080562  147.004210        GMT +6
#
#   Vertical_Datum-str Station_ID-str Site_Description-str Deployment-str  \
# 0               mAHD            462                  462        Profile
# 1               mAHD            462                  462        Profile
# 2               mAHD            462                  462        Profile
# 3               mAHD            462                  462        Profile
# 4               mAHD            462                  462        Profile
#
#   Deployment_Postion-str Vertical_Reference-str
# 0         m from Surface          Water Surface
# 1         m from Surface          Water Surface
# 2         m from Surface          Water Surface
# 3         m from Surface          Water Surface
# 4         m from Surface          Water Surface
#
# [5 rows x 21 columns]
#
# Combined DataFrame for ../../data-warehouse/csv/ht/met/WoodsLakeAtDam_Precipitation_profile_Header.csv and ../../data-warehouse/csv/ht/met/WoodsLakeAtDam_Precipitation_profile_Data.csv:
#   Agency-str Agency_Code-str Program_Name-str Program_Code-str  \
# 0     HT-MET              HT       Woods Lake              MET
# 1     HT-MET              HT       Woods Lake              MET
# 2     HT-MET              HT       Woods Lake              MET
# 3     HT-MET              HT       Woods Lake              MET
# 4     HT-MET              HT       Woods Lake              MET
#
#               Date-str  Data-f64  Depth-f64 Variable_ID-str Variable_Name-str  \
# 0  2015-01-01 01:00:00       0.0          0        var00152          Rainfall
# 1  2015-01-01 02:00:00       0.0          0        var00152          Rainfall
# 2  2015-01-01 03:00:00       0.0          0        var00152          Rainfall
# 3  2015-01-01 04:00:00       0.0          0        var00152          Rainfall
# 4  2015-01-01 05:00:00       0.0          0        var00152          Rainfall
#
#   Data_File_Name-str  ... Status-str     Lat-f64     Lon-f64 Time_Zone-str  \
# 0       Rainfall.csv  ...     Active  -42.080562  147.004210        GMT +6
# 1       Rainfall.csv  ...     Active  -42.080562  147.004210        GMT +6
# 2       Rainfall.csv  ...     Active  -42.080562  147.004210        GMT +6
# 3       Rainfall.csv  ...     Active  -42.080562  147.004210        GMT +6
# 4       Rainfall.csv  ...     Active  -42.080562  147.004210        GMT +6
#
#   Vertical_Datum-str Station_ID-str Site_Description-str Deployment-str  \
# 0               mAHD            462                  462        Profile
# 1               mAHD            462                  462        Profile
# 2               mAHD            462                  462        Profile
# 3               mAHD            462                  462        Profile
# 4               mAHD            462                  462        Profile
#
#   Deployment_Postion-str Vertical_Reference-str
# 0         m from Surface          Water Surface
# 1         m from Surface          Water Surface
# 2         m from Surface          Water Surface
# 3         m from Surface          Water Surface
# 4         m from Surface          Water Surface
#
# [5 rows x 21 columns]

# %%
import os
import pandas as pd

def csv_to_single_row_dataframe(file_path):
    # Read the CSV file
    df = pd.read_csv(file_path)
    
    # Use the first column as headers and the second column as row values
    single_row_df = pd.DataFrame([df.iloc[:, 1].values], columns=df.iloc[:, 0].values)
    
    return single_row_df

def merge_header_and_data(header_path, data_path):
    header_df = csv_to_single_row_dataframe(header_path)
    selected_columns = ['Agency Code', 'Program', 'Project', 'Tag', 'Data File Name', 'Location', 'Station Status', 'Lat', 'Long', 'Time Zone', 'Vertical Datum', 'National Station ID', 'Site Description', 'Deployment', 'Deployment Position', 'Vertical Reference', 'Variable ID']
    header_df = header_df[selected_columns]
    data_df = pd.read_csv(data_path)
    
    # Repeat the header for each row in the data DataFrame
    header_repeated = pd.concat([header_df] * len(data_df), ignore_index=True)
    
    # Combine the header and data DataFrames
    combined_df = pd.concat([header_repeated, data_df], axis=1)
    
    # Rearrange columns as requested
    column_order = ['Tag', 'Agency Code', 'Program', 'Project', 'Date', 'Data', 'Depth', 'Variable ID', 'Variable', 'Data File Name', 'Location', 'Station Status', 'Lat', 'Long', 'Time Zone', 'Vertical Datum', 'National Station ID', 'Site Description', 'Deployment', 'Deployment Position', 'Vertical Reference']
    combined_df = combined_df[column_order]
    
    return combined_df

def find_csv_header_files(directory):
    csv_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith("Header.csv"):
                csv_files.append(os.path.join(root, file))
    return csv_files

def find_csv_data_files(directory):
    csv_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith("Data.csv"):
                csv_files.append(os.path.join(root, file))
    return csv_files

directory = "../../data-warehouse/csv/ht/met"

header_files = find_csv_header_files(directory)
data_files = find_csv_data_files(directory)

# Match header files with corresponding data files
for header_file in header_files:
    # Construct the corresponding data file path
    data_file = header_file.replace("_Header.csv", "_Data.csv")
    
    # Ensure the data file exists before processing
    if data_file in data_files:
        combined_df = merge_header_and_data(header_file, data_file)
        print(f"Combined DataFrame for {header_file} and {data_file}:")
        print(combined_df.head())
        print()
    else:
        print(f"Data file not found for {header_file}")
# Out:
# Combined DataFrame for ../../data-warehouse/csv/ht/met/BOMIDC_Precipitation_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOMIDC_Precipitation_profile_Data.csv:
#       Tag Agency Code Program Project                 Date  Data  Depth  \
# 0  HT-MET          HT     BOM     MET  2000-01-01 00:00:00   NaN      0
# 1  HT-MET          HT     BOM     MET  2000-01-02 00:00:00   NaN      0
# 2  HT-MET          HT     BOM     MET  2000-01-03 00:00:00   NaN      0
# 3  HT-MET          HT     BOM     MET  2000-01-04 00:00:00   NaN      0
# 4  HT-MET          HT     BOM     MET  2000-01-05 00:00:00   NaN      0
#
#   Variable ID    Variable  Data File Name  ... Station Status     Lat    Long  \
# 0    var00152  IDCJAC0009  IDCJAC0009.csv  ...         Active  -41.90  146.67
# 1    var00152  IDCJAC0009  IDCJAC0009.csv  ...         Active  -41.90  146.67
# 2    var00152  IDCJAC0009  IDCJAC0009.csv  ...         Active  -41.90  146.67
# 3    var00152  IDCJAC0009  IDCJAC0009.csv  ...         Active  -41.90  146.67
# 4    var00152  IDCJAC0009  IDCJAC0009.csv  ...         Active  -41.90  146.67
#
#   Time Zone Vertical Datum National Station ID Site Description Deployment  \
# 0    GMT +6           mAHD               96033            96033    Profile
# 1    GMT +6           mAHD               96033            96033    Profile
# 2    GMT +6           mAHD               96033            96033    Profile
# 3    GMT +6           mAHD               96033            96033    Profile
# 4    GMT +6           mAHD               96033            96033    Profile
#
#   Deployment Position Vertical Reference
# 0      m from Surface      Water Surface
# 1      m from Surface      Water Surface
# 2      m from Surface      Water Surface
# 3      m from Surface      Water Surface
# 4      m from Surface      Water Surface
#
# [5 rows x 21 columns]
#
# Combined DataFrame for ../../data-warehouse/csv/ht/met/BOM_WindDirection_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOM_WindDirection_profile_Data.csv:
#       Tag Agency Code Program Project                 Date    Data  Depth  \
# 0  HT-MET          HT     BOM     MET  2011-07-14 14:00:00     NaN      0
# 1  HT-MET          HT     BOM     MET  2011-07-14 15:00:00  225.00      0
# 2  HT-MET          HT     BOM     MET  2011-07-14 16:00:00  236.25      0
# 3  HT-MET          HT     BOM     MET  2011-07-14 17:00:00  236.25      0
# 4  HT-MET          HT     BOM     MET  2011-07-14 18:00:00  236.25      0
#
#   Variable ID Variable Data File Name  ... Station Status         Lat  \
# 0    var00129       WD         WD.csv  ...         Active  -42.080562
# 1    var00129       WD         WD.csv  ...         Active  -42.080562
# 2    var00129       WD         WD.csv  ...         Active  -42.080562
# 3    var00129       WD         WD.csv  ...         Active  -42.080562
# 4    var00129       WD         WD.csv  ...         Active  -42.080562
#
#          Long Time Zone Vertical Datum National Station ID Site Description  \
# 0  147.004210    GMT +6           mAHD                 462              462
# 1  147.004210    GMT +6           mAHD                 462              462
# 2  147.004210    GMT +6           mAHD                 462              462
# 3  147.004210    GMT +6           mAHD                 462              462
# 4  147.004210    GMT +6           mAHD                 462              462
#
#   Deployment Deployment Position Vertical Reference
# 0    Profile      m from Surface      Water Surface
# 1    Profile      m from Surface      Water Surface
# 2    Profile      m from Surface      Water Surface
# 3    Profile      m from Surface      Water Surface
# 4    Profile      m from Surface      Water Surface
#
# [5 rows x 21 columns]
#
# Combined DataFrame for ../../data-warehouse/csv/ht/met/BOM_AirTemperature_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOM_AirTemperature_profile_Data.csv:
#       Tag Agency Code Program Project                 Date   Data  Depth  \
# 0  HT-MET          HT     BOM     MET  2011-07-14 14:00:00    NaN      0
# 1  HT-MET          HT     BOM     MET  2011-07-14 15:00:00  1.550      0
# 2  HT-MET          HT     BOM     MET  2011-07-14 16:00:00  1.050      0
# 3  HT-MET          HT     BOM     MET  2011-07-14 17:00:00  0.475      0
# 4  HT-MET          HT     BOM     MET  2011-07-14 18:00:00  0.125      0
#
#   Variable ID Variable Data File Name  ... Station Status         Lat  \
# 0    var00153  AirTemp    AirTemp.csv  ...         Active  -42.080562
# 1    var00153  AirTemp    AirTemp.csv  ...         Active  -42.080562
# 2    var00153  AirTemp    AirTemp.csv  ...         Active  -42.080562
# 3    var00153  AirTemp    AirTemp.csv  ...         Active  -42.080562
# 4    var00153  AirTemp    AirTemp.csv  ...         Active  -42.080562
#
#          Long Time Zone Vertical Datum National Station ID Site Description  \
# 0  147.004210    GMT +6           mAHD                 462              462
# 1  147.004210    GMT +6           mAHD                 462              462
# 2  147.004210    GMT +6           mAHD                 462              462
# 3  147.004210    GMT +6           mAHD                 462              462
# 4  147.004210    GMT +6           mAHD                 462              462
#
#   Deployment Deployment Position Vertical Reference
# 0    Profile      m from Surface      Water Surface
# 1    Profile      m from Surface      Water Surface
# 2    Profile      m from Surface      Water Surface
# 3    Profile      m from Surface      Water Surface
# 4    Profile      m from Surface      Water Surface
#
# [5 rows x 21 columns]
#
# Combined DataFrame for ../../data-warehouse/csv/ht/met/BOM_RelativeHumidity_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOM_RelativeHumidity_profile_Data.csv:
#       Tag Agency Code Program Project                 Date  Data  Depth  \
# 0  HT-MET          HT     BOM     MET  2011-07-14 14:00:00   NaN      0
# 1  HT-MET          HT     BOM     MET  2011-07-14 15:00:00   NaN      0
# 2  HT-MET          HT     BOM     MET  2011-07-14 16:00:00   NaN      0
# 3  HT-MET          HT     BOM     MET  2011-07-14 17:00:00   NaN      0
# 4  HT-MET          HT     BOM     MET  2011-07-14 18:00:00   NaN      0
#
#   Variable ID  Variable Data File Name  ... Station Status         Lat  \
# 0    var00156  Humidity   Humidity.csv  ...         Active  -42.080562
# 1    var00156  Humidity   Humidity.csv  ...         Active  -42.080562
# 2    var00156  Humidity   Humidity.csv  ...         Active  -42.080562
# 3    var00156  Humidity   Humidity.csv  ...         Active  -42.080562
# 4    var00156  Humidity   Humidity.csv  ...         Active  -42.080562
#
#          Long Time Zone Vertical Datum National Station ID Site Description  \
# 0  147.004210    GMT +6           mAHD                 462              462
# 1  147.004210    GMT +6           mAHD                 462              462
# 2  147.004210    GMT +6           mAHD                 462              462
# 3  147.004210    GMT +6           mAHD                 462              462
# 4  147.004210    GMT +6           mAHD                 462              462
#
#   Deployment Deployment Position Vertical Reference
# 0    Profile      m from Surface      Water Surface
# 1    Profile      m from Surface      Water Surface
# 2    Profile      m from Surface      Water Surface
# 3    Profile      m from Surface      Water Surface
# 4    Profile      m from Surface      Water Surface
#
# [5 rows x 21 columns]
#
# Combined DataFrame for ../../data-warehouse/csv/ht/met/BOM_Precipitation_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOM_Precipitation_profile_Data.csv:
#       Tag Agency Code Program Project                 Date  Data  Depth  \
# 0  HT-MET          HT     BOM     MET  2011-07-15 10:00:00   NaN      0
# 1  HT-MET          HT     BOM     MET  2011-07-15 11:00:00   0.0      0
# 2  HT-MET          HT     BOM     MET  2011-07-15 12:00:00   0.0      0
# 3  HT-MET          HT     BOM     MET  2011-07-15 13:00:00   0.0      0
# 4  HT-MET          HT     BOM     MET  2011-07-15 14:00:00   0.0      0
#
#   Variable ID  Variable  Data File Name  ... Station Status         Lat  \
# 0    var00152  Rainfall  IDCJAC0009.csv  ...         Active  -42.080562
# 1    var00152  Rainfall  IDCJAC0009.csv  ...         Active  -42.080562
# 2    var00152  Rainfall  IDCJAC0009.csv  ...         Active  -42.080562
# 3    var00152  Rainfall  IDCJAC0009.csv  ...         Active  -42.080562
# 4    var00152  Rainfall  IDCJAC0009.csv  ...         Active  -42.080562
#
#          Long Time Zone Vertical Datum National Station ID Site Description  \
# 0  147.004210    GMT +6           mAHD                 462              462
# 1  147.004210    GMT +6           mAHD                 462              462
# 2  147.004210    GMT +6           mAHD                 462              462
# 3  147.004210    GMT +6           mAHD                 462              462
# 4  147.004210    GMT +6           mAHD                 462              462
#
#   Deployment Deployment Position Vertical Reference
# 0    Profile      m from Surface      Water Surface
# 1    Profile      m from Surface      Water Surface
# 2    Profile      m from Surface      Water Surface
# 3    Profile      m from Surface      Water Surface
# 4    Profile      m from Surface      Water Surface
#
# [5 rows x 21 columns]
#
# Combined DataFrame for ../../data-warehouse/csv/ht/met/BOM_WindSpeed_profile_Header.csv and ../../data-warehouse/csv/ht/met/BOM_WindSpeed_profile_Data.csv:
#       Tag Agency Code Program Project                 Date  Data  Depth  \
# 0  HT-MET          HT     BOM     MET  2011-07-14 14:00:00   NaN      0
# 1  HT-MET          HT     BOM     MET  2011-07-14 15:00:00  6.02      0
# 2  HT-MET          HT     BOM     MET  2011-07-14 16:00:00  5.67      0
# 3  HT-MET          HT     BOM     MET  2011-07-14 17:00:00  4.06      0
# 4  HT-MET          HT     BOM     MET  2011-07-14 18:00:00  4.62      0
#
#   Variable ID Variable Data File Name  ... Station Status         Lat  \
# 0    var00130       WS         WS.csv  ...         Active  -42.080562
# 1    var00130       WS         WS.csv  ...         Active  -42.080562
# 2    var00130       WS         WS.csv  ...         Active  -42.080562
# 3    var00130       WS         WS.csv  ...         Active  -42.080562
# 4    var00130       WS         WS.csv  ...         Active  -42.080562
#
#          Long Time Zone Vertical Datum National Station ID Site Description  \
# 0  147.004210    GMT +6           mAHD                 462              462
# 1  147.004210    GMT +6           mAHD                 462              462
# 2  147.004210    GMT +6           mAHD                 462              462
# 3  147.004210    GMT +6           mAHD                 462              462
# 4  147.004210    GMT +6           mAHD                 462              462
#
#   Deployment Deployment Position Vertical Reference
# 0    Profile      m from Surface      Water Surface
# 1    Profile      m from Surface      Water Surface
# 2    Profile      m from Surface      Water Surface
# 3    Profile      m from Surface      Water Surface
# 4    Profile      m from Surface      Water Surface
#
# [5 rows x 21 columns]
#
# Combined DataFrame for ../../data-warehouse/csv/ht/met/WoodsLakeAtDam_Precipitation_profile_Header.csv and ../../data-warehouse/csv/ht/met/WoodsLakeAtDam_Precipitation_profile_Data.csv:
#       Tag Agency Code     Program Project                 Date  Data  Depth  \
# 0  HT-MET          HT  Woods Lake     MET  2015-01-01 01:00:00   0.0      0
# 1  HT-MET          HT  Woods Lake     MET  2015-01-01 02:00:00   0.0      0
# 2  HT-MET          HT  Woods Lake     MET  2015-01-01 03:00:00   0.0      0
# 3  HT-MET          HT  Woods Lake     MET  2015-01-01 04:00:00   0.0      0
# 4  HT-MET          HT  Woods Lake     MET  2015-01-01 05:00:00   0.0      0
#
#   Variable ID  Variable Data File Name  ... Station Status         Lat  \
# 0    var00152  Rainfall   Rainfall.csv  ...         Active  -42.080562
# 1    var00152  Rainfall   Rainfall.csv  ...         Active  -42.080562
# 2    var00152  Rainfall   Rainfall.csv  ...         Active  -42.080562
# 3    var00152  Rainfall   Rainfall.csv  ...         Active  -42.080562
# 4    var00152  Rainfall   Rainfall.csv  ...         Active  -42.080562
#
#          Long Time Zone Vertical Datum National Station ID Site Description  \
# 0  147.004210    GMT +6           mAHD                 462              462
# 1  147.004210    GMT +6           mAHD                 462              462
# 2  147.004210    GMT +6           mAHD                 462              462
# 3  147.004210    GMT +6           mAHD                 462              462
# 4  147.004210    GMT +6           mAHD                 462              462
#
#   Deployment Deployment Position Vertical Reference
# 0    Profile      m from Surface      Water Surface
# 1    Profile      m from Surface      Water Surface
# 2    Profile      m from Surface      Water Surface
# 3    Profile      m from Surface      Water Surface
# 4    Profile      m from Surface      Water Surface
#
# [5 rows x 21 columns]

# %%
import os
import pandas as pd

def csv_to_single_row_dataframe(file_path):
    # Read the CSV file
    df = pd.read_csv(file_path)
    
    # Use the first column as headers and the second column as row values
    single_row_df = pd.DataFrame([df.iloc[:, 1].values], columns=df.iloc[:, 0].values)
    
    return single_row_df

def merge_header_and_data(header_path, data_path):
    header_df = csv_to_single_row_dataframe(header_path)
    selected_columns = ['Agency Code', 'Program', 'Project', 'Tag', 'Data File Name', 'Location', 'Station Status', 'Lat', 'Long', 'Time Zone', 'Vertical Datum', 'National Station ID', 'Site Description', 'Deployment', 'Deployment Position', 'Vertical Reference']
    header_df = header_df[selected_columns]
    data_df = pd.read_csv(data_path)
    
    # Repeat the header for each row in the data DataFrame
    header_repeated = pd.concat([header_df] * len(data_df), ignore_index=True)
    
    # Combine the header and data DataFrames
    combined_df = pd.concat([header_repeated, data_df], axis=1)
    
    return combined_df

def find_csv_header_files(directory):
    csv_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith("Header.csv"):
                csv_files.append(os.path.join(root, file))
    return csv_files

def find_csv_data_files(directory):
    csv_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith("Data.csv"):
                csv_files.append(os.path.join(root, file))
    return csv_files

directory = "../../data-warehouse/csv/ht/met"

header_files = find_csv_header_files(directory)
data_files = find_csv_data_files(directory)

# Match header files with corresponding data files
for header_file in header_files:
    # Construct the corresponding data file path
    data_file = header_file.replace("_Header.csv", "_Data.csv")
    
    # Ensure the data file exists before processing
    if data_file in data_files:
        combined_df = merge_header_and_data(header_file, data_file)
        # # Ensure column selection is correct, adjust as per your requirement
        # selected_columns = ['Agency Code', 'Program', 'Project', 'Tag', 'Data File Name', 'Location', 'Station Status', 'Lat', 'Long', 'Time Zone', 'Vertical Datum', 'National Station ID', 'Site Description', 'Deployment', 'Deployment Position', 'Vertical Reference']
        # combined_df = combined_df[selected_columns + combined_df.columns[-5:-2].tolist()]

        # Print or process combined_df as needed
        # print(f"Combined DataFrame for {header_file} and {data_file}:")
        print(combined_df.head())
        # print(combined_df.columns.values.tolist())
        print()
    else:
        print(f"Data file not found for {header_file}")
# Out:
#   Agency Code Program Project     Tag  Data File Name            Location  \
# 0          HT     BOM     MET  HT-MET  IDCJAC0009.csv  data-lake/BOM/IDC/
# 1          HT     BOM     MET  HT-MET  IDCJAC0009.csv  data-lake/BOM/IDC/
# 2          HT     BOM     MET  HT-MET  IDCJAC0009.csv  data-lake/BOM/IDC/
# 3          HT     BOM     MET  HT-MET  IDCJAC0009.csv  data-lake/BOM/IDC/
# 4          HT     BOM     MET  HT-MET  IDCJAC0009.csv  data-lake/BOM/IDC/
#
#   Station Status     Lat    Long Time Zone  ... National Station ID  \
# 0         Active  -41.90  146.67    GMT +6  ...               96033
# 1         Active  -41.90  146.67    GMT +6  ...               96033
# 2         Active  -41.90  146.67    GMT +6  ...               96033
# 3         Active  -41.90  146.67    GMT +6  ...               96033
# 4         Active  -41.90  146.67    GMT +6  ...               96033
#
#   Site Description Deployment Deployment Position Vertical Reference  \
# 0            96033    Profile      m from Surface      Water Surface
# 1            96033    Profile      m from Surface      Water Surface
# 2            96033    Profile      m from Surface      Water Surface
# 3            96033    Profile      m from Surface      Water Surface
# 4            96033    Profile      m from Surface      Water Surface
#
#      Variable                 Date Depth  Data   QC
# 0  IDCJAC0009  2000-01-01 00:00:00     0   NaN  NaN
# 1  IDCJAC0009  2000-01-02 00:00:00     0   NaN  NaN
# 2  IDCJAC0009  2000-01-03 00:00:00     0   NaN  NaN
# 3  IDCJAC0009  2000-01-04 00:00:00     0   NaN  NaN
# 4  IDCJAC0009  2000-01-05 00:00:00     0   NaN  NaN
#
# [5 rows x 21 columns]
#
#   Agency Code Program Project     Tag Data File Name  \
# 0          HT     BOM     MET  HT-MET         WD.csv
# 1          HT     BOM     MET  HT-MET         WD.csv
# 2          HT     BOM     MET  HT-MET         WD.csv
# 3          HT     BOM     MET  HT-MET         WD.csv
# 4          HT     BOM     MET  HT-MET         WD.csv
#
#                              Location Station Status         Lat        Long  \
# 0  data-lake/BOM/HT/Hourly aggregate/         Active  -42.080562  147.004210
# 1  data-lake/BOM/HT/Hourly aggregate/         Active  -42.080562  147.004210
# 2  data-lake/BOM/HT/Hourly aggregate/         Active  -42.080562  147.004210
# 3  data-lake/BOM/HT/Hourly aggregate/         Active  -42.080562  147.004210
# 4  data-lake/BOM/HT/Hourly aggregate/         Active  -42.080562  147.004210
#
#   Time Zone  ... National Station ID Site Description Deployment  \
# 0    GMT +6  ...                 462              462    Profile
# 1    GMT +6  ...                 462              462    Profile
# 2    GMT +6  ...                 462              462    Profile
# 3    GMT +6  ...                 462              462    Profile
# 4    GMT +6  ...                 462              462    Profile
#
#   Deployment Position Vertical Reference Variable                 Date Depth  \
# 0      m from Surface      Water Surface       WD  2011-07-14 14:00:00     0
# 1      m from Surface      Water Surface       WD  2011-07-14 15:00:00     0
# 2      m from Surface      Water Surface       WD  2011-07-14 16:00:00     0
# 3      m from Surface      Water Surface       WD  2011-07-14 17:00:00     0
# 4      m from Surface      Water Surface       WD  2011-07-14 18:00:00     0
#
#      Data  QC
# 0     NaN   N
# 1  225.00   N
# 2  236.25   N
# 3  236.25   N
# 4  236.25   N
#
# [5 rows x 21 columns]
#
#   Agency Code Program Project     Tag Data File Name  \
# 0          HT     BOM     MET  HT-MET    AirTemp.csv
# 1          HT     BOM     MET  HT-MET    AirTemp.csv
# 2          HT     BOM     MET  HT-MET    AirTemp.csv
# 3          HT     BOM     MET  HT-MET    AirTemp.csv
# 4          HT     BOM     MET  HT-MET    AirTemp.csv
#
#                              Location Station Status         Lat        Long  \
# 0  data-lake/BOM/HT/Hourly aggregate/         Active  -42.080562  147.004210
# 1  data-lake/BOM/HT/Hourly aggregate/         Active  -42.080562  147.004210
# 2  data-lake/BOM/HT/Hourly aggregate/         Active  -42.080562  147.004210
# 3  data-lake/BOM/HT/Hourly aggregate/         Active  -42.080562  147.004210
# 4  data-lake/BOM/HT/Hourly aggregate/         Active  -42.080562  147.004210
#
#   Time Zone  ... National Station ID Site Description Deployment  \
# 0    GMT +6  ...                 462              462    Profile
# 1    GMT +6  ...                 462              462    Profile
# 2    GMT +6  ...                 462              462    Profile
# 3    GMT +6  ...                 462              462    Profile
# 4    GMT +6  ...                 462              462    Profile
#
#   Deployment Position Vertical Reference Variable                 Date Depth  \
# 0      m from Surface      Water Surface  AirTemp  2011-07-14 14:00:00     0
# 1      m from Surface      Water Surface  AirTemp  2011-07-14 15:00:00     0
# 2      m from Surface      Water Surface  AirTemp  2011-07-14 16:00:00     0
# 3      m from Surface      Water Surface  AirTemp  2011-07-14 17:00:00     0
# 4      m from Surface      Water Surface  AirTemp  2011-07-14 18:00:00     0
#
#     Data  QC
# 0    NaN   N
# 1  1.550   N
# 2  1.050   N
# 3  0.475   N
# 4  0.125   N
#
# [5 rows x 21 columns]
#
#   Agency Code Program Project     Tag Data File Name  \
# 0          HT     BOM     MET  HT-MET   Humidity.csv
# 1          HT     BOM     MET  HT-MET   Humidity.csv
# 2          HT     BOM     MET  HT-MET   Humidity.csv
# 3          HT     BOM     MET  HT-MET   Humidity.csv
# 4          HT     BOM     MET  HT-MET   Humidity.csv
#
#                              Location Station Status         Lat        Long  \
# 0  data-lake/BOM/HT/Hourly aggregate/         Active  -42.080562  147.004210
# 1  data-lake/BOM/HT/Hourly aggregate/         Active  -42.080562  147.004210
# 2  data-lake/BOM/HT/Hourly aggregate/         Active  -42.080562  147.004210
# 3  data-lake/BOM/HT/Hourly aggregate/         Active  -42.080562  147.004210
# 4  data-lake/BOM/HT/Hourly aggregate/         Active  -42.080562  147.004210
#
#   Time Zone  ... National Station ID Site Description Deployment  \
# 0    GMT +6  ...                 462              462    Profile
# 1    GMT +6  ...                 462              462    Profile
# 2    GMT +6  ...                 462              462    Profile
# 3    GMT +6  ...                 462              462    Profile
# 4    GMT +6  ...                 462              462    Profile
#
#   Deployment Position Vertical Reference  Variable                 Date Depth  \
# 0      m from Surface      Water Surface  Humidity  2011-07-14 14:00:00     0
# 1      m from Surface      Water Surface  Humidity  2011-07-14 15:00:00     0
# 2      m from Surface      Water Surface  Humidity  2011-07-14 16:00:00     0
# 3      m from Surface      Water Surface  Humidity  2011-07-14 17:00:00     0
# 4      m from Surface      Water Surface  Humidity  2011-07-14 18:00:00     0
#
#    Data  QC
# 0   NaN   N
# 1   NaN   N
# 2   NaN   N
# 3   NaN   N
# 4   NaN   N
#
# [5 rows x 21 columns]
#
#   Agency Code Program Project     Tag  Data File Name  \
# 0          HT     BOM     MET  HT-MET  IDCJAC0009.csv
# 1          HT     BOM     MET  HT-MET  IDCJAC0009.csv
# 2          HT     BOM     MET  HT-MET  IDCJAC0009.csv
# 3          HT     BOM     MET  HT-MET  IDCJAC0009.csv
# 4          HT     BOM     MET  HT-MET  IDCJAC0009.csv
#
#                              Location Station Status         Lat        Long  \
# 0  data-lake/BOM/HT/Hourly aggregate/         Active  -42.080562  147.004210
# 1  data-lake/BOM/HT/Hourly aggregate/         Active  -42.080562  147.004210
# 2  data-lake/BOM/HT/Hourly aggregate/         Active  -42.080562  147.004210
# 3  data-lake/BOM/HT/Hourly aggregate/         Active  -42.080562  147.004210
# 4  data-lake/BOM/HT/Hourly aggregate/         Active  -42.080562  147.004210
#
#   Time Zone  ... National Station ID Site Description Deployment  \
# 0    GMT +6  ...                 462              462    Profile
# 1    GMT +6  ...                 462              462    Profile
# 2    GMT +6  ...                 462              462    Profile
# 3    GMT +6  ...                 462              462    Profile
# 4    GMT +6  ...                 462              462    Profile
#
#   Deployment Position Vertical Reference  Variable                 Date Depth  \
# 0      m from Surface      Water Surface  Rainfall  2011-07-15 10:00:00     0
# 1      m from Surface      Water Surface  Rainfall  2011-07-15 11:00:00     0
# 2      m from Surface      Water Surface  Rainfall  2011-07-15 12:00:00     0
# 3      m from Surface      Water Surface  Rainfall  2011-07-15 13:00:00     0
# 4      m from Surface      Water Surface  Rainfall  2011-07-15 14:00:00     0
#
#    Data  QC
# 0   NaN   N
# 1   0.0   N
# 2   0.0   N
# 3   0.0   N
# 4   0.0   N
#
# [5 rows x 21 columns]
#
#   Agency Code Program Project     Tag Data File Name  \
# 0          HT     BOM     MET  HT-MET         WS.csv
# 1          HT     BOM     MET  HT-MET         WS.csv
# 2          HT     BOM     MET  HT-MET         WS.csv
# 3          HT     BOM     MET  HT-MET         WS.csv
# 4          HT     BOM     MET  HT-MET         WS.csv
#
#                              Location Station Status         Lat        Long  \
# 0  data-lake/BOM/HT/Hourly aggregate/         Active  -42.080562  147.004210
# 1  data-lake/BOM/HT/Hourly aggregate/         Active  -42.080562  147.004210
# 2  data-lake/BOM/HT/Hourly aggregate/         Active  -42.080562  147.004210
# 3  data-lake/BOM/HT/Hourly aggregate/         Active  -42.080562  147.004210
# 4  data-lake/BOM/HT/Hourly aggregate/         Active  -42.080562  147.004210
#
#   Time Zone  ... National Station ID Site Description Deployment  \
# 0    GMT +6  ...                 462              462    Profile
# 1    GMT +6  ...                 462              462    Profile
# 2    GMT +6  ...                 462              462    Profile
# 3    GMT +6  ...                 462              462    Profile
# 4    GMT +6  ...                 462              462    Profile
#
#   Deployment Position Vertical Reference Variable                 Date Depth  \
# 0      m from Surface      Water Surface       WS  2011-07-14 14:00:00     0
# 1      m from Surface      Water Surface       WS  2011-07-14 15:00:00     0
# 2      m from Surface      Water Surface       WS  2011-07-14 16:00:00     0
# 3      m from Surface      Water Surface       WS  2011-07-14 17:00:00     0
# 4      m from Surface      Water Surface       WS  2011-07-14 18:00:00     0
#
#    Data  QC
# 0   NaN   N
# 1  6.02   N
# 2  5.67   N
# 3  4.06   N
# 4  4.62   N
#
# [5 rows x 21 columns]
#
#   Agency Code     Program Project     Tag Data File Name  \
# 0          HT  Woods Lake     MET  HT-MET   Rainfall.csv
# 1          HT  Woods Lake     MET  HT-MET   Rainfall.csv
# 2          HT  Woods Lake     MET  HT-MET   Rainfall.csv
# 3          HT  Woods Lake     MET  HT-MET   Rainfall.csv
# 4          HT  Woods Lake     MET  HT-MET   Rainfall.csv
#
#                     Location Station Status         Lat        Long Time Zone  \
# 0  data-lake/HT/Meteorology/         Active  -42.080562  147.004210    GMT +6
# 1  data-lake/HT/Meteorology/         Active  -42.080562  147.004210    GMT +6
# 2  data-lake/HT/Meteorology/         Active  -42.080562  147.004210    GMT +6
# 3  data-lake/HT/Meteorology/         Active  -42.080562  147.004210    GMT +6
# 4  data-lake/HT/Meteorology/         Active  -42.080562  147.004210    GMT +6
#
#    ... National Station ID Site Description Deployment Deployment Position  \
# 0  ...                 462              462    Profile      m from Surface
# 1  ...                 462              462    Profile      m from Surface
# 2  ...                 462              462    Profile      m from Surface
# 3  ...                 462              462    Profile      m from Surface
# 4  ...                 462              462    Profile      m from Surface
#
#   Vertical Reference  Variable                 Date Depth  Data  QC
# 0      Water Surface  Rainfall  2015-01-01 01:00:00     0   0.0   N
# 1      Water Surface  Rainfall  2015-01-01 02:00:00     0   0.0   N
# 2      Water Surface  Rainfall  2015-01-01 03:00:00     0   0.0   N
# 3      Water Surface  Rainfall  2015-01-01 04:00:00     0   0.0   N
# 4      Water Surface  Rainfall  2015-01-01 05:00:00     0   0.0   N
#
# [5 rows x 21 columns]

# %%
import os
import pandas as pd

def csv_to_single_row_dataframe(file_path):
    # Read the CSV file
    df = pd.read_csv(file_path)
    
    # Use the first column as headers and the second column as row values
    single_row_df = pd.DataFrame([df.iloc[:, 1].values], columns=df.iloc[:, 0].values)
    
    return single_row_df

def merge_header_and_data(header_path, data_path):
    header_df = csv_to_single_row_dataframe(header_path)
    data_df = pd.read_csv(data_path)
    
    # Repeat the header for each row in the data DataFrame
    header_repeated = pd.concat([header_df] * len(data_df), ignore_index=True)
    
    # Combine the header and data DataFrames
    combined_df = pd.concat([header_repeated, data_df], axis=1)
    
    return combined_df

def find_csv_header_files(directory):
    csv_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith("Header.csv"):
                csv_files.append(os.path.join(root, file))
    return csv_files

def find_csv_data_files(directory):
    csv_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith("Data.csv"):
                csv_files.append(os.path.join(root, file))
    return csv_files

directory = "../../data-warehouse/csv/ht/met"

header_files = find_csv_header_files(directory)
data_files = find_csv_data_files(directory)

# # Example usage with the provided files
# header_file = "../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_AirTemperature_profile_Header.csv"
# data_file = "../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_AirTemperature_profile_Data.csv"

combined_df = merge_header_and_data(header_file, data_file)

# Print the combined DataFrame
print(combined_df)

# %%
import os
import pandas as pd

def find_csv_file_pairs(directory):
    csv_file_pairs = []
    
    for root, _, files in os.walk(directory):
        header_files = [file for file in files if file.endswith("Header.csv")]
        
        for header_file in header_files:
            data_file = header_file.replace("Header.csv", "Data.csv")
            if data_file in files:
                csv_file_pairs.append((os.path.join(root, header_file), os.path.join(root, data_file)))
    
    return csv_file_pairs

def csv_to_single_row_dataframe(file_path):
    # Read the CSV file
    df = pd.read_csv(file_path)
    
    # Use the first column as headers and the second column as row values
    single_row_df = pd.DataFrame([df.iloc[:, 1].values], columns=df.iloc[:, 0].values)
    
    return single_row_df

def merge_header_and_data(header_path, data_path):
    header_df = csv_to_single_row_dataframe(header_path)
    data_df = pd.read_csv(data_path)
    
    # Repeat the header for each row in the data DataFrame
    header_repeated = pd.concat([header_df] * len(data_df), ignore_index=True)
    
    # Combine the header and data DataFrames
    combined_df = pd.concat([header_repeated, data_df], axis=1)
    
    return combined_df

def convert_and_rename_columns(df):
    # Convert all columns to string, except for "Lat" and "Long"
    df = df.astype({'Tag': str, 'Agency Code': str, 'Program': str, 'Project': str, 'Variable ID': str, 'Data File Name': str, 'Location': str, 'Station Status': str, 'Time Zone': str, 'Vertical Datum': str, 'National Station ID': str, 'Site Description': str, 'Deployment': str, 'Deployment Position': str, 'Vertical Reference': str})
    df['Lat'] = pd.to_numeric(df['Lat'])
    df['Long'] = pd.to_numeric(df['Long'])
    
    # Determine the data type of each column and create new column names
    new_column_names = [f"{col}-{df[col].dtype}" for col in df.columns]

    # Create a mapping from original column names to new column names
    column_name_mapping = dict(zip(df.columns, new_column_names))

    # Rename columns in the DataFrame
    df.rename(columns=column_name_mapping, inplace=True)
    
    return df

def process_files(directory):
    csv_file_pairs = find_csv_file_pairs(directory)

    combined_df_list = []

    for header_file, data_file in csv_file_pairs:
        combined_df = merge_header_and_data(header_file, data_file)
        combined_df_list.append(combined_df)
    
    if combined_df_list:
        final_df = pd.concat(combined_df_list, ignore_index=True)
        final_df = convert_and_rename_columns(final_df)
    else:
        final_df = pd.DataFrame()

    return final_df

# Define the desired column order
column_order = [
    "Tag", "Agency Code", "Program", "Project", "Variable ID", "Data File Name",
    "Location", "Station Status", "Lat", "Long", "Time Zone", "Vertical Datum",
    "National Station ID", "Site Description", "Deployment", "Deployment Position",
    "Vertical Reference"
]

directory = "../../data-warehouse/csv/ht/met"
# output_path = "../../data-warehouse/parquet/agency/csiem_HT_public.csv"

final_df = process_files(directory)

# Reorder columns based on the specified order
if not final_df.empty:
    final_df = final_df[column_order]
    # Save to CSV if needed
    # final_df.to_csv(output_path, index=False)

print(final_df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 83
#      80 directory = "../../data-warehouse/csv/ht/met"
#      81 # output_path = "../../data-warehouse/parquet/agency/csiem_HT_public.csv"
# ---> 83 final_df = process_files(directory)
#      85 # Reorder columns based on the specified order
#      86 if not final_df.empty:
#
# Cell In[4], line 61, in process_files(directory)
#      58 combined_df_list = []
#      60 for header_file, data_file in csv_file_pairs:
# ---> 61     combined_df = merge_header_and_data(header_file, data_file)
#      62     combined_df_list.append(combined_df)
#      64 if combined_df_list:
#
# Cell In[4], line 31, in merge_header_and_data(header_path, data_path)
#      28 data_df = pd.read_csv(data_path)
#      30 # Repeat the header for each row in the data DataFrame
# ---> 31 header_repeated = pd.concat([header_df] * len(data_df), ignore_index=True)
#      33 # Combine the header and data DataFrames
#      34 combined_df = pd.concat([header_repeated, data_df], axis=1)
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/reshape/concat.py:393, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     378     copy = False
#     380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#    (...)
#     390     sort=sort,
#     391 )
# --> 393 return op.get_result()
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/reshape/concat.py:680, in _Concatenator.get_result(self)
#     676             indexers[ax] = obj_labels.get_indexer(new_labels)
#     678     mgrs_indexers.append((obj._mgr, indexers))
# --> 680 new_data = concatenate_managers(
#     681     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     682 )
#     683 if not self.copy and not using_copy_on_write():
#     684     new_data._consolidate_inplace()
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/internals/concat.py:157, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     154     out.axes = axes
#     155     return out
# --> 157 concat_plan = _get_combined_plan(mgrs)
#     159 blocks = []
#     160 values: ArrayLike
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/internals/concat.py:313, in _get_combined_plan(mgrs)
#     310 for k, mgr in enumerate(mgrs):
#     311     blkno = blknos[k]
# --> 313     nb = _get_block_for_concat_plan(mgr, bp, blkno, max_len=max_len)
#     314     unit = JoinUnit(nb)
#     315     units_for_bp.append(unit)
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/internals/concat.py:342, in _get_block_for_concat_plan(mgr, bp, blkno, max_len)
#     339 # TODO: in all extant test cases 2023-04-08 we have a slice here.
#     340 #  Will this always be the case?
#     341 if isinstance(slc, slice):
# --> 342     nb = blk.slice_block_columns(slc)
#     343 else:
#     344     nb = blk.take_block_columns(slc)
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/internals/blocks.py:306, in Block.slice_block_columns(self, slc)
#     304 new_values = self._slice(slc)
#     305 refs = self.refs
# --> 306 return type(self)(new_values, new_mgr_locs, self.ndim, refs=refs)
#
# KeyboardInterrupt:

# %%
import os
import pandas as pd

def find_csv_files(directory, suffix):
    csv_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(suffix):
                csv_files.append(os.path.join(root, file))
    return csv_files

def csv_to_single_row_dataframe(file_path):
    # Read the CSV file
    df = pd.read_csv(file_path)
    
    # Use the first column as headers and the second column as row values
    single_row_df = pd.DataFrame([df.iloc[:, 1].values], columns=df.iloc[:, 0].values)
    
    return single_row_df

def merge_header_and_data(header_path, data_path):
    header_df = csv_to_single_row_dataframe(header_path)
    data_df = pd.read_csv(data_path)
    
    # Repeat the header for each row in the data DataFrame
    header_repeated = pd.concat([header_df] * len(data_df), ignore_index=True)
    
    # Combine the header and data DataFrames
    combined_df = pd.concat([header_repeated, data_df], axis=1)
    
    return combined_df

def convert_and_rename_columns(df):
    # Convert all columns to string, except for "Lat" and "Long"
    df = df.astype({'Tag': str, 'Agency Code': str, 'Program': str, 'Project': str, 'Variable ID': str, 'Data File Name': str, 'Location': str, 'Station Status': str, 'Time Zone': str, 'Vertical Datum': str, 'National Station ID': str, 'Site Description': str, 'Deployment': str, 'Deployment Position': str, 'Vertical Reference': str})
    df['Lat'] = pd.to_numeric(df['Lat'])
    df['Long'] = pd.to_numeric(df['Long'])
    
    # Determine the data type of each column and create new column names
    new_column_names = []
    for col in df.columns:
        data_type = df[col].dtype
        new_col_name = f"{col}-{data_type}"
        new_column_names.append(new_col_name)

    # Create a mapping from original column names to new column names
    column_name_mapping = dict(zip(df.columns, new_column_names))

    # Rename columns in the DataFrame
    df.rename(columns=column_name_mapping, inplace=True)
    
    return df

def process_files(directory):
    header_files = find_csv_files(directory, "Header.csv")
    data_files = find_csv_files(directory, "Data.csv")

    combined_df_list = []

    for header_file in header_files:
        # Find the corresponding data file
        data_file = header_file.replace("Header.csv", "Data.csv")
        
        if data_file in data_files:
            combined_df = merge_header_and_data(header_file, data_file)
            combined_df_list.append(combined_df)
    
    if combined_df_list:
        final_df = pd.concat(combined_df_list, ignore_index=True)
        final_df = convert_and_rename_columns(final_df)
        return final_df
    else:
        return pd.DataFrame()

# Define the desired column order
column_order = [
    "Tag", "Agency Code", "Program", "Project", "Date", "Data", "Depth", "Variable ID", "Variable_Name", "Data File Name", "Location", "Station Status", "Lat", "Long", "Time Zone", "Vertical Datum", "National Station ID", "Site Description" "Deployment", "Deployment Position", "Vertical Reference"
]

directory = "../../data-warehouse/csv/ht"
# output_path = "../../data-warehouse/parquet/agency/csiem_HT_public.csv"

final_df = process_files(directory)

# Reorder columns based on the specified order
if not final_df.empty:
    final_df = final_df[column_order]
    # Save to CSV if needed
    # final_df.to_csv(output_path, index=False)

print(final_df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 83
#      80 directory = "../../data-warehouse/csv/ht"
#      81 # output_path = "../../data-warehouse/parquet/agency/csiem_HT_public.csv"
# ---> 83 final_df = process_files(directory)
#      85 # Reorder columns based on the specified order
#      86 if not final_df.empty:
#
# Cell In[3], line 65, in process_files(directory)
#      62     data_file = header_file.replace("Header.csv", "Data.csv")
#      64     if data_file in data_files:
# ---> 65         combined_df = merge_header_and_data(header_file, data_file)
#      66         combined_df_list.append(combined_df)
#      68 if combined_df_list:
#
# Cell In[3], line 26, in merge_header_and_data(header_path, data_path)
#      23 data_df = pd.read_csv(data_path)
#      25 # Repeat the header for each row in the data DataFrame
# ---> 26 header_repeated = pd.concat([header_df] * len(data_df), ignore_index=True)
#      28 # Combine the header and data DataFrames
#      29 combined_df = pd.concat([header_repeated, data_df], axis=1)
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/reshape/concat.py:393, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     378     copy = False
#     380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#    (...)
#     390     sort=sort,
#     391 )
# --> 393 return op.get_result()
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/reshape/concat.py:680, in _Concatenator.get_result(self)
#     676             indexers[ax] = obj_labels.get_indexer(new_labels)
#     678     mgrs_indexers.append((obj._mgr, indexers))
# --> 680 new_data = concatenate_managers(
#     681     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     682 )
#     683 if not self.copy and not using_copy_on_write():
#     684     new_data._consolidate_inplace()
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/internals/concat.py:157, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     154     out.axes = axes
#     155     return out
# --> 157 concat_plan = _get_combined_plan(mgrs)
#     159 blocks = []
#     160 values: ArrayLike
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/internals/concat.py:313, in _get_combined_plan(mgrs)
#     310 for k, mgr in enumerate(mgrs):
#     311     blkno = blknos[k]
# --> 313     nb = _get_block_for_concat_plan(mgr, bp, blkno, max_len=max_len)
#     314     unit = JoinUnit(nb)
#     315     units_for_bp.append(unit)
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/internals/concat.py:342, in _get_block_for_concat_plan(mgr, bp, blkno, max_len)
#     339 # TODO: in all extant test cases 2023-04-08 we have a slice here.
#     340 #  Will this always be the case?
#     341 if isinstance(slc, slice):
# --> 342     nb = blk.slice_block_columns(slc)
#     343 else:
#     344     nb = blk.take_block_columns(slc)
#
# File ~/.pyenv/versions/3.11.5/lib/python3.11/site-packages/pandas/core/internals/blocks.py:306, in Block.slice_block_columns(self, slc)
#     304 new_values = self._slice(slc)
#     305 refs = self.refs
# --> 306 return type(self)(new_values, new_mgr_locs, self.ndim, refs=refs)
#
# KeyboardInterrupt:

# %%
import os
import pandas as pd

def find_csv_files(directory):
    csv_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith("Header.csv"):
                csv_files.append(os.path.join(root, file))
    return csv_files

def csv_to_single_row_dataframe(file_path):
    # Read the CSV file
    df = pd.read_csv(file_path)
    
    # Use the first column as headers and the second column as row values
    single_row_df = pd.DataFrame([df.iloc[:, 1].values], columns=df.iloc[:, 0].values)
    
    return single_row_df

def merge_csv_files(directory, column_order):
    csv_files = find_csv_files(directory)
    merged_df = pd.DataFrame()
    for file in csv_files:
        single_row_df = csv_to_single_row_dataframe(file)
        merged_df = pd.concat([merged_df, single_row_df], ignore_index=True)
    
    # Reorder columns based on the specified order
    merged_df = merged_df[column_order]
    
    return merged_df

def convert_and_rename_columns(df):
    # Convert all columns to string, except for "Lat" and "Long"
    df = df.astype({'Tag': str, 'Agency Code': str, 'Program': str, 'Project': str, 'Variable ID': str, 'Data File Name': str, 'Location': str, 'Station Status': str, 'Time Zone': str, 'Vertical Datum': str, 'National Station ID': str, 'Site Description': str, 'Deployment': str, 'Deployment Position': str, 'Vertical Reference': str})
    df['Lat'] = pd.to_numeric(df['Lat'])
    df['Long'] = pd.to_numeric(df['Long'])
    
    # Determine the data type of each column and create new column names
    new_column_names = []
    for col in df.columns:
        data_type = df[col].dtype
        new_col_name = f"{col}-{data_type}"
        new_column_names.append(new_col_name)

    # Create a mapping from original column names to new column names
    column_name_mapping = dict(zip(df.columns, new_column_names))

    # Rename columns in the DataFrame
    df.rename(columns=column_name_mapping, inplace=True)
    
    return df

# Define the desired column order
column_order = [
    "Tag", "Agency Code", "Program", "Project", "Variable ID", "Data File Name",
    "Location", "Station Status", "Lat", "Long", "Time Zone", "Vertical Datum",
    "National Station ID", "Site Description", "Deployment", "Deployment Position",
    "Vertical Reference"
]

directory = "../../data-warehouse/csv/ht"
# output_path = "../../data-warehouse/parquet/agency/csiem_HT_public.csv"

merged_df = merge_csv_files(directory, column_order)

# Convert data types and rename columns
merged_df = convert_and_rename_columns(merged_df)

# save_merged_csv(merged_df, output_path)

print(merged_df)
# Out:
#     Tag-object Agency Code-object   Program-object Project-object  \
# 0      HT-ALWQ                 HT  Arthurs Lake WQ           ALWQ
# 1      HT-ALWQ                 HT  Arthurs Lake WQ           ALWQ
# 2      HT-ALWQ                 HT  Arthurs Lake WQ           ALWQ
# 3      HT-ALWQ                 HT  Arthurs Lake WQ           ALWQ
# 4      HT-ALWQ                 HT  Arthurs Lake WQ           ALWQ
# ..         ...                ...              ...            ...
# 300    HT-WLWQ                 HT    Woods Lake WQ           WLWQ
# 301    HT-WLWQ                 HT    Woods Lake WQ           WLWQ
# 302    HT-WLWQ                 HT    Woods Lake WQ           WLWQ
# 303    HT-WLWQ                 HT    Woods Lake WQ           WLWQ
# 304    HT-WLWQ                 HT    Woods Lake WQ           WLWQ
#
#     Variable ID-object              Data File Name-object  \
# 0             var00755                      WQSamples.csv
# 1             var00014                      WQSamples.csv
# 2             var00023                      WQSamples.csv
# 3             var00627                      WQSamples.csv
# 4             var00660                      WQSamples.csv
# ..                 ...                                ...
# 300           var00671  462.5_WoodsLakeMiddle_AllData.csv
# 301           var00675  462.5_WoodsLakeMiddle_AllData.csv
# 302           var00759  462.5_WoodsLakeMiddle_AllData.csv
# 303           var00735  462.5_WoodsLakeMiddle_AllData.csv
# 304           var00715  462.5_WoodsLakeMiddle_AllData.csv
#
#                                        Location-object Station Status-object  \
# 0    data-lake/HT/Hydrology/Arthurs Lake Spillway (...                Active
# 1    data-lake/HT/Hydrology/Arthurs Lake Spillway (...                Active
# 2    data-lake/HT/Hydrology/Arthurs Lake Spillway (...                Active
# 3    data-lake/HT/Hydrology/Arthurs Lake Spillway (...                Active
# 4    data-lake/HT/Hydrology/Arthurs Lake Spillway (...                Active
# ..                                                 ...                   ...
# 300                         data-lake/HT/WaterQuality/                Active
# 301                         data-lake/HT/WaterQuality/                Active
# 302                         data-lake/HT/WaterQuality/                Active
# 303                         data-lake/HT/WaterQuality/                Active
# 304                         data-lake/HT/WaterQuality/                Active
#
#      Lat-float64  Long-float64 Time Zone-object Vertical Datum-object  \
# 0     -41.985227    146.992343           GMT +6                  mAHD
# 1     -41.985227    146.992343           GMT +6                  mAHD
# 2     -41.985227    146.992343           GMT +6                  mAHD
# 3     -41.985227    146.992343           GMT +6                  mAHD
# 4     -41.985227    146.992343           GMT +6                  mAHD
# ..           ...           ...              ...                   ...
# 300   -42.080562    147.004210           GMT +6                  mAHD
# 301   -42.080562    147.004210           GMT +6                  mAHD
# 302   -42.080562    147.004210           GMT +6                  mAHD
# 303   -42.080562    147.004210           GMT +6                  mAHD
# 304   -42.080562    147.004210           GMT +6                  mAHD
#
#     National Station ID-object Site Description-object Deployment-object  \
# 0                          418                     418           Profile
# 1                          418                     418           Profile
# 2                          418                     418           Profile
# 3                          418                     418           Profile
# 4                          418                     418           Profile
# ..                         ...                     ...               ...
# 300                        462                     462           Profile
# 301                        462                     462           Profile
# 302                        462                     462           Profile
# 303                        462                     462           Profile
# 304                        462                     462           Profile
#
#     Deployment Position-object Vertical Reference-object
# 0               m from Surface             Water Surface
# 1               m from Surface             Water Surface
# 2               m from Surface             Water Surface
# 3               m from Surface             Water Surface
# 4               m from Surface             Water Surface
# ..                         ...                       ...
# 300             m from Surface             Water Surface
# 301             m from Surface             Water Surface
# 302             m from Surface             Water Surface
# 303             m from Surface             Water Surface
# 304             m from Surface             Water Surface
#
# [305 rows x 17 columns]

# %%
import pandas as pd

def merge_header_and_data(header_path, data_path):
    header_df = csv_to_single_row_dataframe(header_path)
    data_df = pd.read_csv(data_path)
    
    # Repeat the header for each row in the data DataFrame
    header_repeated = pd.concat([header_df] * len(data_df), ignore_index=True)
    
    # Combine the header and data DataFrames
    combined_df = pd.concat([header_repeated, data_df], axis=1)
    
    return combined_df

# Example usage with the provided files
header_file = "../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_AirTemperature_profile_Header.csv"
data_file = "../../data-warehouse/csv/ht/alwq/ArthursLakeSpillway_AirTemperature_profile_Data.csv"

combined_df = merge_header_and_data(header_file, data_file)

# Print the combined DataFrame
print(combined_df)
# Out:
#        Agency Name Agency Code          Program Project      Tag  \
# 0   Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 1   Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 2   Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 3   Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 4   Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 5   Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 6   Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 7   Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 8   Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 9   Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 10  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 11  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 12  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 13  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 14  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 15  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 16  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 17  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 18  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 19  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 20  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 21  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 22  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 23  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 24  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 25  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 26  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 27  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 28  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 29  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 30  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 31  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 32  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 33  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 34  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 35  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 36  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 37  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 38  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 39  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 40  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 41  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 42  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
# 43  Hydro Tasmania          HT  Arthurs Lake WQ    ALWQ  HT-ALWQ
#
#    Data File Name                                           Location  \
# 0   WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 1   WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 2   WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 3   WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 4   WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 5   WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 6   WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 7   WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 8   WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 9   WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 10  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 11  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 12  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 13  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 14  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 15  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 16  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 17  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 18  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 19  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 20  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 21  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 22  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 23  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 24  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 25  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 26  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 27  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 28  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 29  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 30  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 31  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 32  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 33  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 34  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 35  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 36  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 37  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 38  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 39  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 40  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 41  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 42  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
# 43  WQSamples.csv  data-lake/HT/Hydrology/Arthurs Lake Spillway (...
#
#    Station Status         Lat        Long  ... Sampling Rate (min)  \
# 0          Active  -41.985227  146.992343  ...                 NaN
# 1          Active  -41.985227  146.992343  ...                 NaN
# 2          Active  -41.985227  146.992343  ...                 NaN
# 3          Active  -41.985227  146.992343  ...                 NaN
# 4          Active  -41.985227  146.992343  ...                 NaN
# 5          Active  -41.985227  146.992343  ...                 NaN
# 6          Active  -41.985227  146.992343  ...                 NaN
# 7          Active  -41.985227  146.992343  ...                 NaN
# 8          Active  -41.985227  146.992343  ...                 NaN
# 9          Active  -41.985227  146.992343  ...                 NaN
# 10         Active  -41.985227  146.992343  ...                 NaN
# 11         Active  -41.985227  146.992343  ...                 NaN
# 12         Active  -41.985227  146.992343  ...                 NaN
# 13         Active  -41.985227  146.992343  ...                 NaN
# 14         Active  -41.985227  146.992343  ...                 NaN
# 15         Active  -41.985227  146.992343  ...                 NaN
# 16         Active  -41.985227  146.992343  ...                 NaN
# 17         Active  -41.985227  146.992343  ...                 NaN
# 18         Active  -41.985227  146.992343  ...                 NaN
# 19         Active  -41.985227  146.992343  ...                 NaN
# 20         Active  -41.985227  146.992343  ...                 NaN
# 21         Active  -41.985227  146.992343  ...                 NaN
# 22         Active  -41.985227  146.992343  ...                 NaN
# 23         Active  -41.985227  146.992343  ...                 NaN
# 24         Active  -41.985227  146.992343  ...                 NaN
# 25         Active  -41.985227  146.992343  ...                 NaN
# 26         Active  -41.985227  146.992343  ...                 NaN
# 27         Active  -41.985227  146.992343  ...                 NaN
# 28         Active  -41.985227  146.992343  ...                 NaN
# 29         Active  -41.985227  146.992343  ...                 NaN
# 30         Active  -41.985227  146.992343  ...                 NaN
# 31         Active  -41.985227  146.992343  ...                 NaN
# 32         Active  -41.985227  146.992343  ...                 NaN
# 33         Active  -41.985227  146.992343  ...                 NaN
# 34         Active  -41.985227  146.992343  ...                 NaN
# 35         Active  -41.985227  146.992343  ...                 NaN
# 36         Active  -41.985227  146.992343  ...                 NaN
# 37         Active  -41.985227  146.992343  ...                 NaN
# 38         Active  -41.985227  146.992343  ...                 NaN
# 39         Active  -41.985227  146.992343  ...                 NaN
# 40         Active  -41.985227  146.992343  ...                 NaN
# 41         Active  -41.985227  146.992343  ...                 NaN
# 42         Active  -41.985227  146.992343  ...                 NaN
# 43         Active  -41.985227  146.992343  ...                 NaN
#
#                    Date    Depth         Variable   QC         Variable  \
# 0   yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 1   yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 2   yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 3   yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 4   yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 5   yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 6   yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 7   yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 8   yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 9   yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 10  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 11  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 12  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 13  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 14  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 15  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 16  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 17  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 18  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 19  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 20  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 21  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 22  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 23  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 24  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 25  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 26  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 27  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 28  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 29  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 30  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 31  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 32  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 33  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 34  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 35  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 36  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 37  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 38  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 39  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 40  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 41  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 42  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
# 43  yyyy-mm-dd HH:MM:SS  Decimal  Air Temperature  int  Air Temperature
#
#                    Date  Depth  Data  QC
# 0   2015-09-10 10:25:00    0.0   9.5  11
# 1   2015-11-11 10:25:00    0.0  10.0  11
# 2   2016-01-28 10:30:00    0.0  16.1  11
# 3   2016-03-31 15:35:00    0.0  15.0  11
# 4   2016-05-26 12:25:00    0.0   6.0  11
# 5   2016-07-21 12:20:00    0.0   6.0  11
# 6   2016-09-14 12:40:00    0.0   8.0  11
# 7   2016-11-24 13:00:00    0.0   8.0  11
# 8   2017-01-27 15:05:00    0.0  18.0  11
# 9   2017-02-22 12:40:00    0.0  15.0  11
# 10  2017-04-28 09:20:00    0.0   8.0  11
# 11  2017-06-21 16:30:00    0.0   1.0  11
# 12  2017-07-25 17:00:00    0.0   1.0  11
# 13  2017-09-11 16:35:00    0.0   7.0  11
# 14  2017-10-18 10:00:00    0.0  20.0  11
# 15  2017-11-23 17:05:00    0.0  23.0  11
# 16  2018-01-11 18:10:00    0.0  22.0  11
# 17  2018-03-22 15:10:00    0.0  11.0  11
# 18  2018-05-08 14:15:00    0.0  10.0  11
# 19  2018-07-26 14:25:00    0.0   1.0  11
# 20  2018-09-26 12:25:00    0.0   7.0  11
# 21  2018-11-28 10:40:00    0.0  11.0  11
# 22  2019-01-09 16:30:00    0.0  18.0  11
# 23  2019-02-13 17:15:00    0.0   6.0  11
# 24  2019-03-12 16:15:00    0.0   8.0  11
# 25  2019-04-16 14:00:00    0.0  14.0  11
# 26  2019-05-22 09:25:00    0.0   6.0  11
# 27  2019-06-20 11:55:00    0.0   4.0  11
# 28  2019-07-23 16:55:00    0.0   6.0  11
# 29  2019-08-27 14:45:00    0.0  13.0  11
# 30  2019-09-26 09:05:00    0.0   6.0  11
# 31  2019-10-23 08:55:00    0.0  10.0  11
# 32  2019-11-19 15:05:00    0.0  16.0  11
# 33  2019-12-16 12:45:00    0.0  15.0  11
# 34  2020-01-23 11:55:00    0.0  15.0  11
# 35  2020-02-17 15:40:00    0.0  22.0  11
# 36  2020-05-13 13:35:00    0.0   5.0  11
# 37  2020-06-10 14:40:00    0.0   6.0  11
# 38  2020-08-13 09:59:00    0.0   4.0  11
# 39  2020-10-20 14:30:00    0.0  16.0  11
# 40  2020-12-22 14:15:00    0.0  10.0  11
# 41  2021-02-24 11:05:00    0.0  12.0  11
# 42  2021-04-29 13:50:00    0.0  13.0  11
# 43  2021-06-22 12:35:00    0.0   6.0  11
#
# [44 rows x 32 columns]

# %%
import os
import glob
import pandas as pd
from datetime import datetime
import pyarrow.parquet as pq
import pyarrow as pa

def csv_2_parquet_by_agency():
    # Load variable key
    import importlib.util
    varkey_spec = importlib.util.spec_from_file_location("varkey", "../functions/varkey.py")
    varkey = importlib.util.module_from_spec(varkey_spec)
    varkey_spec.loader.exec_module(varkey)
    
    # Load data paths
    import td_data_paths
    datapath = td_data_paths.datapath
    outfilepath = os.path.join(datapath, 'data-warehouse/parquet/agency/')
    filepath = os.path.join(datapath, 'data-warehouse/csv/')
    
    os.makedirs(outfilepath, exist_ok=True)
    
    filelist = glob.glob(os.path.join(filepath, '**/*Header.csv'), recursive=True)
    
    agency = []
    data = []
    
    for file in filelist:
        print(file)
        header = import_header(file)
        data.append({'header': header})
        agency.append(header['Agency_Code'])
    
    unique_agency = list(set(agency))
    
    for ag in unique_agency:
        find_agency = [i for i, x in enumerate(agency) if x == ag]
        
        tab = create_blank_table()
        tablefield = list(tab.keys())
        
        for ff in find_agency:
            print(filelist[ff])
            
            headerfile = filelist[ff]
            datafile = headerfile.replace('Header', 'Data')
            
            header = import_header(headerfile)
            header['calc_SMD'] = 0
            header['mAHD'] = 0
            
            tt2 = import_datafile_raw(datafile)
            print('Finished Import')
            
            dt = (tt2['Date'].diff().mean()).total_seconds() / 86400
            
            tab11 = pd.DataFrame(tt2)
            tab11['Date'] = pd.to_datetime(tab11['Date'])
            
            if dt < 1/(60*24):
                if header['Deployment'] != 'Profile':
                    print('Starting Downsample')
                    tt = tab11.resample('T').nearest()
                else:
                    tt = tab11
                print('Finished Downsample')
            else:
                tt = tab11
            
            csiem = {'Date': tt['Date'], 'Data': tt['Data'].astype(float), 'Depth': []}
            
            if header['Deployment'] == 'Integrated':
                csiem['Depth'] = tt['Depth']
            elif header['Deployment'] == 'Fixed':
                if 'Height' in tt.columns:
                    csiem['Depth'] = (float(header['calc_SMD']) - tt['Height'].astype(float)) * -1
                else:
                    csiem['Depth'] = tt['Depth'].astype(float) * -1
            elif header['Deployment'] == 'Floating':
                if 'Height' in tt.columns:
                    csiem['Depth'] = tt['Height'].astype(float) * -1
                else:
                    csiem['Depth'] = tt['Depth'].astype(float) * -1
            elif header['Deployment'] in ['Profile', 'Satellite']:
                csiem['Depth'] = tt['Depth'].astype(float) * -1
            else:
                print('Not recognised Deployment')
            
            for k in header.keys():
                csiem[k] = header[k]
            
            csiem['X'] = header['Lon']
            csiem['Y'] = header['Lat']
            csiem['XUTM'] = header['X']
            csiem['YUTM'] = header['Y']
            csiem['Agency'] = header['Tag']
            csiem['Units'] = varkey.varkey[header['Variable_ID']]['tfvUnits']
            
            for k in tablefield:
                if k == 'Date':
                    tab['Date'].extend(csiem['Date'].dt.strftime('%Y-%m-%d %H:%M:%S'))
                elif k == 'Data':
                    tab['Data'].extend(csiem['Data'])
                elif k == 'Depth':
                    if isinstance(csiem['Depth'], list):
                        tab['Depth'].extend(csiem['Depth'])
                    else:
                        tab['Depth'].extend([0] * len(csiem['Date']))
                else:
                    tab[k].extend(appenddata(csiem['Date'], csiem[k]))
        
        newtable = pd.DataFrame.from_dict(tab)
        outfile = os.path.join(outfilepath, f'csiem_{ag}_public.parq')
        table = pa.Table.from_pandas(newtable)
        pq.write_table(table, outfile)
        print(f'Written {outfile}')

def import_header(file):
    # Placeholder for actual import_header function
    return {}

def import_datafile_raw(file):
    # Placeholder for actual import_datafile_raw function
    return {}

def create_blank_table():
    # Placeholder for actual create_blank_table function
    return {'Date': [], 'Data': [], 'Depth': []}

def appenddata(date, data):
    # Placeholder for actual appenddata function
    return data

if __name__ == "__main__":
    csv_2_parquet_by_agency()
