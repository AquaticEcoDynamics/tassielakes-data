# %%
import pandas as pd

phycocyanin = pd.read_csv("../../../data-warehouse/csv/ht/wlwq/WoodsLakeMiddleSurfaceContinuous_Phycocyanin_profile_Data.csv")
print(phycocyanin)

cyanobacteria = pd.read_csv("../../../data-warehouse/csv/ht/wlwq/WoodsLakeMiddle_PhytoplanktonBiomass(cyano)_profile_Data.csv")
print(cyanobacteria)
# Out:
#            Variable                 Date  Depth  Data QC
# 0       phycocyanin  2016-01-07 13:15:00      0  0.29  N
# 1       phycocyanin  2016-01-07 13:23:20      0  0.29  N
# 2       phycocyanin  2016-01-07 13:25:00      0  0.31  N
# 3       phycocyanin  2016-01-07 13:26:45      0  0.30  N
# 4       phycocyanin  2016-01-07 13:30:00      0  0.30  N
# ...             ...                  ...    ...   ... ..
# 288946  phycocyanin  2024-07-24 13:45:00      0  6.66  N
# 288947  phycocyanin  2024-07-24 14:00:00      0  6.55  N
# 288948  phycocyanin  2024-07-24 14:15:00      0  6.14  N
# 288949  phycocyanin  2024-07-24 14:30:00      0  6.32  N
# 288950  phycocyanin  2024-07-24 14:45:00      0  6.79  N
#
# [288951 rows x 5 columns]
#           Variable                 Date  Depth         Data   QC
# 0    Cyanobacteria  2014-01-08 15:00:00    0.2    2475000.0  4.0
# 1    Cyanobacteria  2014-05-12 13:45:00    0.2     770000.0  4.0
# 2    Cyanobacteria  2014-07-23 09:40:00    0.2     357500.0  4.0
# 3    Cyanobacteria  2014-09-18 09:50:00    0.2     165000.0  4.0
# 4    Cyanobacteria  2014-11-21 11:30:00    0.2     214500.0  4.0
# ..             ...                  ...    ...          ...  ...
# 100  Cyanobacteria  2024-01-08 14:55:00    0.2  178750000.0  4.0
# 101  Cyanobacteria  2024-01-18 15:30:00    0.2  286000000.0  4.0
# 102  Cyanobacteria  2024-01-25 11:20:00    0.2  357500000.0  4.0
# 103  Cyanobacteria  2024-02-08 15:05:00    0.2  390000000.0  4.0
# 104  Cyanobacteria  2024-02-16 10:20:00    0.2  357500000.0  4.0
#
# [105 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

phycocyanin['Date'] = pd.to_datetime(phycocyanin['Date'], format='%Y-%m-%d %H:%M:%S')
cyanobacteria['Date'] = pd.to_datetime(cyanobacteria['Date'], format='%Y-%m-%d %H:%M:%S')

start_date = '2023-01-01'
end_date = '2024-01-01'

phycocyanin_filtered = phycocyanin[(phycocyanin['Date'] >= start_date) & (phycocyanin['Date'] <= end_date)]
print(phycocyanin_filtered)
cyanobacteria_filtered = cyanobacteria[(cyanobacteria['Date'] >= start_date) & (cyanobacteria['Date'] <= end_date)]
print(cyanobacteria_filtered)

# Plot the data
fig, ax = plt.subplots(figsize=(14,7))
ax2 = ax.twinx()

ax.plot(phycocyanin_filtered['Date'], phycocyanin_filtered['Data'], label='phycocyanin', color='black')
ax2.plot(cyanobacteria_filtered['Date'], cyanobacteria_filtered['Data'], label='cyanobacteria', color='red')

# Combine legends for both axes
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax.legend(lines + lines2, labels + labels2, loc='upper right')

ax.set_xlabel('Date')
ax.set_ylabel('Phycocyanin (pigment)')
ax2.set_ylabel('Cyanobacteria (mmol/m^3)')

plt.title('Correlation Comparison')

plt.show()
# Out:
#            Variable                Date  Depth  Data QC
# 237317  phycocyanin 2023-01-01 00:00:00      0  0.15  N
# 237318  phycocyanin 2023-01-01 00:15:00      0  0.15  N
# 237319  phycocyanin 2023-01-01 00:30:00      0  0.19  N
# 237320  phycocyanin 2023-01-01 00:45:00      0  0.17  N
# 237321  phycocyanin 2023-01-01 01:00:00      0  0.16  N
# ...             ...                 ...    ...   ... ..
# 271627  phycocyanin 2023-12-31 23:00:00      0  3.85  N
# 271628  phycocyanin 2023-12-31 23:15:00      0  3.80  N
# 271629  phycocyanin 2023-12-31 23:30:00      0  3.78  N
# 271630  phycocyanin 2023-12-31 23:45:00      0  3.84  N
# 271631  phycocyanin 2024-01-01 00:00:00      0  3.68  N
#
# [34315 rows x 5 columns]
#          Variable                Date  Depth         Data   QC
# 65  Cyanobacteria 2023-02-24 11:40:00    0.2  144500000.0  4.0
# 66  Cyanobacteria 2023-03-09 11:50:00    0.2  156750000.0  4.0
# 67  Cyanobacteria 2023-03-20 12:15:00    0.2  105750000.0  4.0
# 68  Cyanobacteria 2023-03-24 11:25:00    0.2  247000000.0  4.0
# 69  Cyanobacteria 2023-03-31 11:15:00    0.2  182475000.0  4.0
# 70  Cyanobacteria 2023-04-05 12:25:00    0.2  225000000.0  4.0
# 71  Cyanobacteria 2023-04-14 11:20:00    0.2  267525000.0  4.0
# 72  Cyanobacteria 2023-04-20 13:25:00    0.2  245550000.0  4.0
# 73  Cyanobacteria 2023-04-28 11:30:00    0.2  278775000.0  4.0
# 74  Cyanobacteria 2023-05-12 12:15:00    0.2  422940000.0  4.0
# 75  Cyanobacteria 2023-05-24 15:25:00    0.2  273030250.0  4.0
# 76  Cyanobacteria 2023-06-07 13:00:00    0.2  325000000.0  4.0
# 77  Cyanobacteria 2023-06-22 13:30:00    0.2  256750000.0  4.0
# 78  Cyanobacteria 2023-07-06 10:50:00    0.2  201500000.0  4.0
# 79  Cyanobacteria 2023-07-19 11:17:00    0.2  126750000.0  4.0
# 80  Cyanobacteria 2023-08-02 12:20:00    0.2   48750000.0  4.0
# 81  Cyanobacteria 2023-08-10 13:05:00    0.2   18526925.0  4.0
# 82  Cyanobacteria 2023-08-15 16:00:00    0.2   16250000.0  4.0
# 83  Cyanobacteria 2023-08-23 12:00:00    0.2    1072500.0  4.0
# 84  Cyanobacteria 2023-08-30 13:40:00    0.2   11375000.0  4.0
# 85  Cyanobacteria 2023-09-06 13:05:00    0.2    6500000.0  4.0
# 86  Cyanobacteria 2023-09-13 15:35:00    0.2    7800000.0  4.0
# 87  Cyanobacteria 2023-09-20 11:15:00    0.2    6175000.0  4.0
# 88  Cyanobacteria 2023-09-28 12:30:00    0.2    5200000.0  4.0
# 89  Cyanobacteria 2023-10-04 15:45:00    0.2     845000.0  4.0
# 90  Cyanobacteria 2023-10-10 15:30:00    0.2    2145000.0  4.0
# 91  Cyanobacteria 2023-10-17 16:00:00    0.2    2333750.0  4.0
# 92  Cyanobacteria 2023-11-02 16:20:00    0.2    2242500.0  4.0
# 93  Cyanobacteria 2023-11-10 16:55:00    0.2    3250000.0  4.0
# 94  Cyanobacteria 2023-11-22 15:10:00    0.2    4225000.0  4.0
# 95  Cyanobacteria 2023-11-29 11:00:00    0.2    5200000.0  4.0
# 96  Cyanobacteria 2023-12-07 10:45:00    0.2   11700000.0  4.0
# 97  Cyanobacteria 2023-12-14 12:20:00    0.2   30875000.0  4.0
# 98  Cyanobacteria 2023-12-18 12:30:00    0.2   42250000.0  4.0
